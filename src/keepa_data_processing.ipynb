# %% [markdown]
# # Processing Keepa Data

# %% [markdown]
# ## Sales Rank Data Processing Documentation
#
# ### Overview
# This documentation describes the process of extracting and analyzing sales rank data from Keepa's product data stored in pickle files. The program converts Keepa's proprietary time format to EST dates and creates visualizations and CSV exports of sales rank trends.
#
# ### Data Structure
# Input Data (Pickle Files)
# The raw data is stored in pickle files with the following relevant fields:
# ```
# {
#     'asin': str,                # Amazon product identifier
#     'title': str,               # Product title
#     'salesRankReference': int,  # Reference category ID
#     'salesRanks': {            # Sales rank history by category
#         'category_id': [keepa_time, rank, keepa_time, rank, ...]
#     }
# }
# ```
#
# #### Key Data Fields
# **1. salesRankReference:**
# - Integer value representing the main category ID
# - Special values: -1 (not available), -2 (listed in launchpad)
#
# **2. salesRanks:**
# - Dictionary with category IDs as keys
# - Values are lists alternating between Keepa time and sales rank
# Data Processing Steps
#
#
# ### Data Processing Steps
# 1. Time Conversion
# 2. Sales Rank Data Extraction
# 3. Output Files

# %% [markdown]
# ## Initialization

# %%
import pickle
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import pytz

# %% [markdown]
# ### Step 1. Time Conversion

# %%
def keepa_to_est(keepa_time):
    """
    Convert Keepa time to EST datetime
    Formula: unix_time = (keepa_time + 21564000) * 60
    """
    unix_time = (keepa_time + 21564000) * 60  # Convert to seconds
    utc_time = datetime.fromtimestamp(unix_time, tz=pytz.UTC)
    est_time = utc_time.astimezone(pytz.timezone('US/Eastern'))
    return est_time.strftime('%Y-%m-%d')

# %% [markdown]
# ### Step 2. Sales Rank Data Extraction

# %%
def process_sales_ranks(pickle_path):
    """
    Process steps:
    1. Load pickle file
    2. Get reference category
    3. Extract sales rank data
    4. Convert time format
    5. Create date-rank dictionary
    """
    # Load pickle file
    with open(pickle_path, 'rb') as f:
        data = pickle.load(f)
    
    # Get reference category
    ref_category = str(data.get('salesRankReference'))
    if not ref_category or ref_category == '-1' or ref_category == '-2':
        print(f"No valid sales rank reference for {pickle_path}")
        return None
    
    # Get sales rank data
    sales_ranks = data.get('salesRanks', {})
    if not sales_ranks or ref_category not in sales_ranks:
        print(f"No sales rank data for category {ref_category}")
        return None
    
    # Process time series data
    rank_data = sales_ranks[ref_category]
    sales_dict = {}
    
    # Convert list to dictionary with EST dates
    for i in range(0, len(rank_data), 2):
        keepa_time = rank_data[i]
        rank = rank_data[i + 1]
        est_date = keepa_to_est(keepa_time)
        sales_dict[est_date] = rank
    
    return {
        'asin': data.get('asin'),
        'title': data.get('title'),
        'category': ref_category,
        'sales_data': sales_dict
    }

# %% [markdown]
# ### Output Files
# 1. CSV File ({ASIN}_sales_rank.csv)
# Format: Date-indexed time series
# ```
# Date, Sales Rank
# 2024-01-01, 1000
# 2024-01-02, 999
# ...
# ```
#
# 2. Visualization ({ASIN}_sales_rank.png)
# Line plot showing sales rank trends over time
# Features:
# - Title with ASIN and product name
# - Date on x-axis
# - Sales rank on y-axis
# - Grid for better readability
#
# ### Data Format Details
# #### Input Time Format
# - Keepa time: Minutes since May 17th, 2011
# - Conversion formula: unix_time = (keepa_time + 21564000) * 60
# #### Output Time Format
# - Date format: 'YYYY-MM-DD'
# - Timezone: US Eastern Time (EST/EDT)
# #### Sales Rank Values
# - Lower numbers indicate better sales performance
# - Raw integer values preserved from original data
# - Missing or invalid data points are excluded

# %%
def plot_sales_rank(sales_data, output_dir):
    """Plot sales rank data and save to CSV"""
    asin = sales_data['asin']
    title = sales_data['title']
    
    # Create DataFrame
    df = pd.DataFrame.from_dict(sales_data['sales_data'], 
                               orient='index', 
                               columns=['Sales Rank'])
    df.index = pd.to_datetime(df.index)
    df = df.sort_index()
    
    # Plot
    plt.figure(figsize=(15, 7))
    plt.plot(df.index, df['Sales Rank'])
    plt.title(f'Sales Rank History for {asin}\n{title}')
    plt.xlabel('Date')
    plt.ylabel('Sales Rank')
    plt.grid(True)
    plt.xticks(rotation=45)
    
    # Save plot
    plt.tight_layout()
    plt.savefig(output_dir / f'sales_rank_figures/{asin}_sales_rank.png')
    plt.close()
    
    # Save CSV
    df.to_csv(output_dir / f'sales_rank_csv/{asin}_sales_rank.csv')
    
    return df

# %%
def main():
    # Setup paths
    base_path = Path('/Users/takedownccp/Documents/Cursor/DDU/data')
    raw_data_path = base_path / 'raw_data'
    output_path = base_path / 'processed_data'
    output_path.mkdir(exist_ok=True)
    
    # Process all pickle files
    # pickle_files = list(raw_data_path.glob('*_raw.pkl'))
    pickle_files = ['B0CHTZ6NCL_raw.pkl', 'B07N52NLC3_raw.pkl', 'B09MZ9T3KT_raw.pkl', 'B09MZBXNHP_raw.pkl', 'B09QL5K6LW_raw.pkl', 'B09ZLSR8PH_raw.pkl']
    
    for pickle_file in pickle_files:
        print(f"\nProcessing {pickle_file.name}")
        
        # Process sales rank data
        sales_data = process_sales_ranks(pickle_file)
        
        if sales_data:
            print(f"Found sales rank data for {sales_data['asin']}")
            print(f"Category: {sales_data['category']}")
            print(f"Data points: {len(sales_data['sales_data'])}")
            
            # Plot and save data
            df = plot_sales_rank(sales_data, output_path)
            print(f"Data saved to {output_path}")
            
            # Display first few rows
            print("\nFirst few data points:")
            print(df.head())
        else:
            print("No valid sales rank data found")

if __name__ == "__main__":
    main()
# Out:
# Processing B0BHL4C4MW_raw.pkl
# Found sales rank data for B0BHL4C4MW
# Category: 3760901
# Data points: 81
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2024-10-18       11888
# 2024-10-23       10390
# 2024-10-24       12956
# 2024-10-25       12548
# 2024-10-26       12756
#
# Processing B00JT3TP1O_raw.pkl
# Found sales rank data for B00JT3TP1O
# Category: 2619533011
# Data points: 750
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         437
# 2022-12-15         727
# 2022-12-16         766
# 2022-12-17         876
# 2022-12-18        1042
#
# Processing B08HP8SM3J_raw.pkl
# Found sales rank data for B08HP8SM3J
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1052
# 2022-12-15        1020
# 2022-12-16        1164
# 2022-12-17        1070
# 2022-12-18        1094
#
# Processing B0CDLL9WN6_raw.pkl
# Found sales rank data for B0CDLL9WN6
# Category: 2619533011
# Data points: 389
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-10-11           5
# 2023-10-12          14
# 2023-10-13          38
# 2023-10-14          52
# 2023-10-15          74
#
# Processing B0037Z6VLC_raw.pkl
# Found sales rank data for B0037Z6VLC
# Category: 2619533011
# Data points: 657
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-03-21        3812
# 2023-03-22        3925
# 2023-03-23        3608
# 2023-03-24        4438
# 2023-03-25        3684
#
# Processing B01MXWOVXU_raw.pkl
# Found sales rank data for B01MXWOVXU
# Category: 2619533011
# Data points: 602
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         419
# 2022-12-15         394
# 2022-12-16         398
# 2022-12-17         351
# 2022-12-18         413
#
# Processing B005OCX8VC_raw.pkl
# Found sales rank data for B005OCX8VC
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         268
# 2022-12-15         247
# 2022-12-16         258
# 2022-12-17         267
# 2022-12-18         303
#
# Processing B000WFKNO6_raw.pkl
# Found sales rank data for B000WFKNO6
# Category: 2619533011
# Data points: 758
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         221
# 2022-12-15         238
# 2022-12-16         240
# 2022-12-17         236
# 2022-12-18         250
#
# Processing B0B1B4NQ7S_raw.pkl
# Found sales rank data for B0B1B4NQ7S
# Category: 2619533011
# Data points: 748
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         187
# 2022-12-15         211
# 2022-12-16         228
# 2022-12-17         249
# 2022-12-18         249
#
# Processing B07NVY7C4Q_raw.pkl
# Found sales rank data for B07NVY7C4Q
# Category: 2619533011
# Data points: 753
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         718
# 2022-12-15       31633
# 2022-12-16         726
# 2022-12-17         793
# 2022-12-18         739
#
# Processing B09K9FDLFN_raw.pkl
# Found sales rank data for B09K9FDLFN
# Category: 2619533011
# Data points: 752
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         139
# 2022-12-15         153
# 2022-12-16         155
# 2022-12-17         176
# 2022-12-18         191
#
# Processing B0748H3GKN_raw.pkl
# Found sales rank data for B0748H3GKN
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         674
# 2022-12-15         667
# 2022-12-16         721
# 2022-12-17         638
# 2022-12-18         655
#
# Processing B01BMBYKOM_raw.pkl
# Found sales rank data for B01BMBYKOM
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         134
# 2022-12-15         164
# 2022-12-16         220
# 2022-12-17         245
# 2022-12-18         263
#
# Processing B0BQYSJ95C_raw.pkl
# Found sales rank data for B0BQYSJ95C
# Category: 2619533011
# Data points: 561
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-03-05       24055
# 2023-03-06       23489
# 2023-03-07       13063
# 2023-03-08        8408
# 2023-03-09        8983
#
# Processing B003P9XG22_raw.pkl
# Found sales rank data for B003P9XG22
# Category: 2619533011
# Data points: 718
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          18
# 2022-12-15          15
# 2022-12-16          14
# 2022-12-17          15
# 2022-12-18          16
#
# Processing B07GN2V7LR_raw.pkl
# Found sales rank data for B07GN2V7LR
# Category: 2619533011
# Data points: 758
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1191
# 2022-12-15        1019
# 2022-12-16        1245
# 2022-12-17        1043
# 2022-12-18        1125
#
# Processing B075JNLTZD_raw.pkl
# Found sales rank data for B075JNLTZD
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          31
# 2022-12-15          35
# 2022-12-16          35
# 2022-12-17          39
# 2022-12-18          41
#
# Processing B08T4BW9SS_raw.pkl
# Found sales rank data for B08T4BW9SS
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1247
# 2022-12-15       10048
# 2022-12-16        7454
# 2022-12-17        6655
# 2022-12-18        6527
#
# Processing B098P6164W_raw.pkl
# Found sales rank data for B098P6164W
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         652
# 2022-12-15         652
# 2022-12-16         625
# 2022-12-17         580
# 2022-12-18         554
#
# Processing B08QR7XXNH_raw.pkl
# Found sales rank data for B08QR7XXNH
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         444
# 2022-12-15         500
# 2022-12-16         517
# 2022-12-17         561
# 2022-12-18         797
#
# Processing B083FHNR68_raw.pkl
# Found sales rank data for B083FHNR68
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1105
# 2022-12-15        1329
# 2022-12-16        1516
# 2022-12-17        1492
# 2022-12-18        1737
#
# Processing B07JG87X5P_raw.pkl
# Found sales rank data for B07JG87X5P
# Category: 2619533011
# Data points: 344
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2024-02-02         490
# 2024-02-03         673
# 2024-02-04         599
# 2024-02-05         593
# 2024-02-06         520
#
# Processing B01BNRNSB6_raw.pkl
# Found sales rank data for B01BNRNSB6
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         260
# 2022-12-15         252
# 2022-12-16         287
# 2022-12-17         315
# 2022-12-18         339
#
# Processing B09GJJLDWR_raw.pkl
# Found sales rank data for B09GJJLDWR
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1060
# 2022-12-15        1049
# 2022-12-16        1004
# 2022-12-17        1142
# 2022-12-18        1096
#
# Processing B0000AH3RN_raw.pkl
# Found sales rank data for B0000AH3RN
# Category: 2619533011
# Data points: 755
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          31
# 2022-12-15          35
# 2022-12-16          37
# 2022-12-17          40
# 2022-12-18          41
#
# Processing B08NWH6QLS_raw.pkl
# Found sales rank data for B08NWH6QLS
# Category: 2619533011
# Data points: 758
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         654
# 2022-12-15         815
# 2022-12-16         920
# 2022-12-17         889
# 2022-12-18         984
#
# Processing B07D9YCQMS_raw.pkl
# Found sales rank data for B07D9YCQMS
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         411
# 2022-12-15         833
# 2022-12-16         244
# 2022-12-17         441
# 2022-12-18         746
#
# Processing B0CGN1B9TP_raw.pkl
# Found sales rank data for B0CGN1B9TP
# Category: 2619533011
# Data points: 465
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-10-05       79827
# 2023-10-06       83617
# 2023-10-07       59467
# 2023-10-08       29466
# 2023-10-09       16735
#
# Processing B09NWGC624_raw.pkl
# Found sales rank data for B09NWGC624
# Category: 2619533011
# Data points: 753
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        6318
# 2022-12-15        7645
# 2022-12-16        5586
# 2022-12-17        7024
# 2022-12-18        6452
#
# Processing B0747PQL2L_raw.pkl
# Found sales rank data for B0747PQL2L
# Category: 2619533011
# Data points: 758
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1692
# 2022-12-15        1850
# 2022-12-16        1913
# 2022-12-17        1971
# 2022-12-18        2239
#
# Processing B007VGE2X2_raw.pkl
# Found sales rank data for B007VGE2X2
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         303
# 2022-12-15         307
# 2022-12-16         350
# 2022-12-17         344
# 2022-12-18         371
#
# Processing B07DK2BQGF_raw.pkl
# Found sales rank data for B07DK2BQGF
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         262
# 2022-12-15         272
# 2022-12-16         304
# 2022-12-17         300
# 2022-12-18         331
#
# Processing B0858MZ9BY_raw.pkl
# Found sales rank data for B0858MZ9BY
# Category: 2619533011
# Data points: 717
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14      133863
# 2022-12-15      135457
# 2022-12-17      136511
# 2022-12-18      136529
# 2022-12-19      135519
#
# Processing B0000AH3QT_raw.pkl
# Found sales rank data for B0000AH3QT
# Category: 2619533011
# Data points: 750
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          51
# 2022-12-15          54
# 2022-12-16          56
# 2022-12-17          62
# 2022-12-18          82
#
# Processing B01NC0JJGV_raw.pkl
# Found sales rank data for B01NC0JJGV
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         529
# 2022-12-15         487
# 2022-12-16         532
# 2022-12-17         492
# 2022-12-18         511
#
# Processing B0BWBT15X7_raw.pkl
# Found sales rank data for B0BWBT15X7
# Category: 2619533011
# Data points: 611
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-05-03       14126
# 2023-05-04       18434
# 2023-05-05       18523
# 2023-05-06       16253
# 2023-05-07       17060
#
# Processing B004QMX4RY_raw.pkl
# Found sales rank data for B004QMX4RY
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         717
# 2022-12-15         686
# 2022-12-16         749
# 2022-12-17         666
# 2022-12-18         748
#
# Processing B0002J1FOE_raw.pkl
# Found sales rank data for B0002J1FOE
# Category: 2619533011
# Data points: 754
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         479
# 2022-12-15         488
# 2022-12-16         496
# 2022-12-17         448
# 2022-12-18         532
#
# Processing B00935OD9C_raw.pkl
# Found sales rank data for B00935OD9C
# Category: 2619533011
# Data points: 755
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14       68619
# 2022-12-15       81647
# 2022-12-16       72540
# 2022-12-17       78797
# 2022-12-18       48211
#
# Processing B004KDRGD2_raw.pkl
# Found sales rank data for B004KDRGD2
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        2557
# 2022-12-15        2375
# 2022-12-16        2474
# 2022-12-17        2361
# 2022-12-18        2415
#
# Processing B003P9XG9K_raw.pkl
# Found sales rank data for B003P9XG9K
# Category: 2619533011
# Data points: 681
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          18
# 2022-12-15          15
# 2022-12-16          14
# 2022-12-18          16
# 2022-12-20          19
#
# Processing B01HEFT7I4_raw.pkl
# Found sales rank data for B01HEFT7I4
# Category: 2619533011
# Data points: 741
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         539
# 2022-12-15         586
# 2022-12-16         618
# 2022-12-17         627
# 2022-12-18         719
#
# Processing B09BYC7HWJ_raw.pkl
# Found sales rank data for B09BYC7HWJ
# Category: 2619533011
# Data points: 753
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         234
# 2022-12-15         240
# 2022-12-16         268
# 2022-12-17         258
# 2022-12-18         234
#
# Processing B08W8D7RB5_raw.pkl
# Found sales rank data for B08W8D7RB5
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1041
# 2022-12-15         877
# 2022-12-16         904
# 2022-12-17         937
# 2022-12-18         976
#
# Processing B07N72XW67_raw.pkl
# Found sales rank data for B07N72XW67
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          51
# 2022-12-15          56
# 2022-12-16          57
# 2022-12-17          57
# 2022-12-18          62
#
# Processing B00Z9I5PCQ_raw.pkl
# Found sales rank data for B00Z9I5PCQ
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         338
# 2022-12-15       50193
# 2022-12-16         401
# 2022-12-17         414
# 2022-12-18         346
#
# Processing B075PBCJCH_raw.pkl
# Found sales rank data for B075PBCJCH
# Category: 2619533011
# Data points: 758
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         145
# 2022-12-15         163
# 2022-12-16         172
# 2022-12-17         170
# 2022-12-18         198
#
# Processing B00REJU4V0_raw.pkl
# Found sales rank data for B00REJU4V0
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         500
# 2022-12-15         529
# 2022-12-16         578
# 2022-12-17         559
# 2022-12-18         660
#
# Processing B00ZDJ7768_raw.pkl
# Found sales rank data for B00ZDJ7768
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         298
# 2022-12-15         285
# 2022-12-16         311
# 2022-12-17         340
# 2022-12-18         365
#
# Processing B00393HSLY_raw.pkl
# Found sales rank data for B00393HSLY
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        2589
# 2022-12-15        2349
# 2022-12-16        2483
# 2022-12-17        2337
# 2022-12-18        2578
#
# Processing B01H3OA816_raw.pkl
# Found sales rank data for B01H3OA816
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        7226
# 2022-12-15        2691
# 2022-12-16        4953
# 2022-12-17        1589
# 2022-12-18        2321
#
# Processing B00RZDXA7K_raw.pkl
# Found sales rank data for B00RZDXA7K
# Category: 2619533011
# Data points: 530
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-07-29          62
# 2023-07-30         107
# 2023-07-31         111
# 2023-08-01         125
# 2023-08-02         103
#
# Processing B08W74QDW5_raw.pkl
# Found sales rank data for B08W74QDW5
# Category: 2619533011
# Data points: 758
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         265
# 2022-12-15         280
# 2022-12-16         290
# 2022-12-17         294
# 2022-12-18         279
#
# Processing B001VIWGFW_raw.pkl
# Found sales rank data for B001VIWGFW
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          31
# 2022-12-15          35
# 2022-12-16          35
# 2022-12-17          39
# 2022-12-18          41
#
# Processing B071H9R94T_raw.pkl
# Found sales rank data for B071H9R94T
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         936
# 2022-12-15         911
# 2022-12-16        1033
# 2022-12-17        1019
# 2022-12-18        1032
#
# Processing B08VYBKQKS_raw.pkl
# Found sales rank data for B08VYBKQKS
# Category: 2619533011
# Data points: 751
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        2158
# 2022-12-15        2024
# 2022-12-16        2133
# 2022-12-17        1868
# 2022-12-18        1910
#
# Processing B001F2KB4C_raw.pkl
# Found sales rank data for B001F2KB4C
# Category: 2619533011
# Data points: 755
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         386
# 2022-12-15         383
# 2022-12-16         443
# 2022-12-17         487
# 2022-12-18         606
#
# Processing B0BL43MBQK_raw.pkl
# Found sales rank data for B0BL43MBQK
# Category: 2619533011
# Data points: 661
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-03-18         465
# 2023-03-19         427
# 2023-03-20         464
# 2023-03-21         428
# 2023-03-22         557
#
# Processing B016MY21XG_raw.pkl
# Found sales rank data for B016MY21XG
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         546
# 2022-12-15         578
# 2022-12-16         387
# 2022-12-17         439
# 2022-12-18         531
#
# Processing B09ZLSR8PH_raw.pkl
# Found sales rank data for B09ZLSR8PH
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        2988
# 2022-12-15        3333
# 2022-12-16        3504
# 2022-12-17        3589
# 2022-12-18        3253
#
# Processing B07KGY1F9Q_raw.pkl
# Found sales rank data for B07KGY1F9Q
# Category: 2619533011
# Data points: 754
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         188
# 2022-12-15         204
# 2022-12-16         194
# 2022-12-17         220
# 2022-12-18         246
#
# Processing B0C5NTHD2T_raw.pkl
# Found sales rank data for B0C5NTHD2T
# Category: 2619533011
# Data points: 565
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-06-15       92989
# 2023-06-17      100373
# 2023-06-18      116226
# 2023-06-19       87287
# 2023-06-24      162347
#
# Processing B0BKG5F7HG_raw.pkl
# Found sales rank data for B0BKG5F7HG
# Category: 2619533011
# Data points: 745
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-28       50812
# 2022-12-29       10093
# 2022-12-30        7942
# 2022-12-31        7470
# 2023-01-01        3927
#
# Processing B0CMCQKXCL_raw.pkl
# Found sales rank data for B0CMCQKXCL
# Category: 2619533011
# Data points: 174
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2024-02-04      112844
# 2024-02-05      118287
# 2024-02-06      121860
# 2024-02-07      124638
# 2024-02-08      126487
#
# Processing B01KTNNJWI_raw.pkl
# Found sales rank data for B01KTNNJWI
# Category: 2619533011
# Data points: 746
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         557
# 2022-12-15         612
# 2022-12-16         584
# 2022-12-17         609
# 2022-12-18         613
#
# Processing B0033Z4GZY_raw.pkl
# Found sales rank data for B0033Z4GZY
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1577
# 2022-12-15        1775
# 2022-12-16        1605
# 2022-12-17        1854
# 2022-12-18        1817
#
# Processing B00PB35ZYM_raw.pkl
# Found sales rank data for B00PB35ZYM
# Category: 2619533011
# Data points: 738
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-15      116314
# 2022-12-16      115892
# 2022-12-17      113307
# 2022-12-18      111822
# 2022-12-19      111912
#
# Processing B0CQMKFPHM_raw.pkl
# Found sales rank data for B0CQMKFPHM
# Category: 2619533011
# Data points: 375
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-12-31         352
# 2024-01-01         391
# 2024-01-02         424
# 2024-01-03         427
# 2024-01-04         395
#
# Processing B008BZV7Z8_raw.pkl
# Found sales rank data for B008BZV7Z8
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1432
# 2022-12-15        1422
# 2022-12-16        1506
# 2022-12-17        1474
# 2022-12-18        1570
#
# Processing B01EZRBRLE_raw.pkl
# Found sales rank data for B01EZRBRLE
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         608
# 2022-12-15         636
# 2022-12-16         622
# 2022-12-17         631
# 2022-12-18         712
#
# Processing B07MK5G4XV_raw.pkl
# Found sales rank data for B07MK5G4XV
# Category: 2619533011
# Data points: 682
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          17
# 2022-12-15          15
# 2022-12-16          15
# 2022-12-17          15
# 2022-12-18          16
#
# Processing B073SZ6NT8_raw.pkl
# Found sales rank data for B073SZ6NT8
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         615
# 2022-12-15         612
# 2022-12-16         575
# 2022-12-17         586
# 2022-12-18         540
#
# Processing B01BV4IS9S_raw.pkl
# Found sales rank data for B01BV4IS9S
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         502
# 2022-12-15         627
# 2022-12-16         624
# 2022-12-17         681
# 2022-12-18         743
#
# Processing B07ZK3NSJQ_raw.pkl
# Found sales rank data for B07ZK3NSJQ
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         100
# 2022-12-15         126
# 2022-12-16         120
# 2022-12-17         143
# 2022-12-18         164
#
# Processing B000MCVGEA_raw.pkl
# Found sales rank data for B000MCVGEA
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         770
# 2022-12-15         765
# 2022-12-16         813
# 2022-12-17         899
# 2022-12-18         937
#
# Processing B006W6YHYQ_raw.pkl
# Found sales rank data for B006W6YHYQ
# Category: 2619533011
# Data points: 750
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          39
# 2022-12-15          43
# 2022-12-16          43
# 2022-12-17          40
# 2022-12-18          43
#
# Processing B0BCX4939V_raw.pkl
# Found sales rank data for B0BCX4939V
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14       16310
# 2022-12-15       14007
# 2022-12-16       11813
# 2022-12-17       10908
# 2022-12-18        9299
#
# Processing B00HXRYDVK_raw.pkl
# Found sales rank data for B00HXRYDVK
# Category: 2619533011
# Data points: 744
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14       84236
# 2022-12-15       99347
# 2022-12-16      103544
# 2022-12-17      106364
# 2022-12-18       90088
#
# Processing B07BH4CPX1_raw.pkl
# Found sales rank data for B07BH4CPX1
# Category: 2619533011
# Data points: 758
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1395
# 2022-12-15        1435
# 2022-12-16        1060
# 2022-12-17        1056
# 2022-12-18        1174
#
# Processing B083JLRC2M_raw.pkl
# Found sales rank data for B083JLRC2M
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        2432
# 2022-12-15        2713
# 2022-12-16        2611
# 2022-12-17        2327
# 2022-12-18        2767
#
# Processing B0074JN3TU_raw.pkl
# Found sales rank data for B0074JN3TU
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         267
# 2022-12-15         268
# 2022-12-16         319
# 2022-12-17         334
# 2022-12-18         400
#
# Processing B08QMB717R_raw.pkl
# Found sales rank data for B08QMB717R
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         814
# 2022-12-15         904
# 2022-12-16         949
# 2022-12-17         933
# 2022-12-18         899
#
# Processing B0725WN216_raw.pkl
# Found sales rank data for B0725WN216
# Category: 2619533011
# Data points: 751
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14      104276
# 2022-12-15      106026
# 2022-12-16      105262
# 2022-12-17      102051
# 2022-12-18      100578
#
# Processing B0BMDN99N5_raw.pkl
# Found sales rank data for B0BMDN99N5
# Category: 2619533011
# Data points: 745
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-29      109916
# 2022-12-30      120887
# 2022-12-31      142925
# 2023-01-01      158137
# 2023-01-02      176457
#
# Processing B0BGL2GTTM_raw.pkl
# Found sales rank data for B0BGL2GTTM
# Category: 2619533011
# Data points: 656
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-03-28       30646
# 2023-03-29       31106
# 2023-03-30       21933
# 2023-03-31       22089
# 2023-04-01        9701
#
# Processing B0BHKP6YLB_raw.pkl
# Found sales rank data for B0BHKP6YLB
# Category: 3760901
# Data points: 167
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2024-07-28        9097
# 2024-07-29        7589
# 2024-07-30        7587
# 2024-07-31        7583
# 2024-08-01        8173
#
# Processing B005KSGWUY_raw.pkl
# Found sales rank data for B005KSGWUY
# Category: 2619533011
# Data points: 752
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        3199
# 2022-12-15        1790
# 2022-12-16        1755
# 2022-12-17        1769
# 2022-12-18        1819
#
# Processing B09M7PD5L9_raw.pkl
# Found sales rank data for B09M7PD5L9
# Category: 2619533011
# Data points: 755
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          80
# 2022-12-15          74
# 2022-12-16         107
# 2022-12-17          89
# 2022-12-18          91
#
# Processing B08X2LY6HC_raw.pkl
# Found sales rank data for B08X2LY6HC
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1029
# 2022-12-15        1143
# 2022-12-16        1239
# 2022-12-17        1364
# 2022-12-18        1379
#
# Processing B0C3NKNYLD_raw.pkl
# Found sales rank data for B0C3NKNYLD
# Category: 2619533011
# Data points: 578
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-06-07         232
# 2023-06-08         212
# 2023-06-09         247
# 2023-06-10         262
# 2023-06-11         195
#
# Processing B0BWBJ2HHB_raw.pkl
# Found sales rank data for B0BWBJ2HHB
# Category: 2619533011
# Data points: 617
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-05-04       37608
# 2023-05-05       54849
# 2023-05-06       37668
# 2023-05-07       40359
# 2023-05-08       47009
#
# Processing B09NW91XWZ_raw.pkl
# Found sales rank data for B09NW91XWZ
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         838
# 2022-12-15         799
# 2022-12-16         843
# 2022-12-17         880
# 2022-12-18         913
#
# Processing B0000AH3RR_raw.pkl
# Found sales rank data for B0000AH3RR
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          31
# 2022-12-15          35
# 2022-12-16          35
# 2022-12-17          40
# 2022-12-18          41
#
# Processing B000A0PYQK_raw.pkl
# Found sales rank data for B000A0PYQK
# Category: 2619533011
# Data points: 755
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         718
# 2022-12-15         716
# 2022-12-16         722
# 2022-12-17         745
# 2022-12-18         627
#
# Processing B07F6FTTM7_raw.pkl
# Found sales rank data for B07F6FTTM7
# Category: 2619533011
# Data points: 604
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-05-19         531
# 2023-05-20         473
# 2023-05-21         477
# 2023-05-22         502
# 2023-05-23         460
#
# Processing B07TWTSZCR_raw.pkl
# Found sales rank data for B07TWTSZCR
# Category: 2619533011
# Data points: 755
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         417
# 2022-12-15         460
# 2022-12-16         476
# 2022-12-17         484
# 2022-12-18         468
#
# Processing B000MD59TC_raw.pkl
# Found sales rank data for B000MD59TC
# Category: 2619533011
# Data points: 551
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-07-11         589
# 2023-07-12         659
# 2023-07-13         578
# 2023-07-14         490
# 2023-07-15         489
#
# Processing B005OTJWUQ_raw.pkl
# Found sales rank data for B005OTJWUQ
# Category: 2619533011
# Data points: 754
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         336
# 2022-12-15         332
# 2022-12-16         397
# 2022-12-17         390
# 2022-12-18         371
#
# Processing B0C9918D5F_raw.pkl
# Found sales rank data for B0C9918D5F
# Category: 2619533011
# Data points: 458
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-10-09         287
# 2023-10-10         316
# 2023-10-11         304
# 2023-10-12         317
# 2023-10-13         353
#
# Processing B097S7N153_raw.pkl
# Found sales rank data for B097S7N153
# Category: 2619533011
# Data points: 758
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          59
# 2022-12-15          66
# 2022-12-16          71
# 2022-12-17          74
# 2022-12-18          83
#
# Processing B09MZBXNHP_raw.pkl
# Found sales rank data for B09MZBXNHP
# Category: 2619533011
# Data points: 758
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        2287
# 2022-12-15        2012
# 2022-12-16        2404
# 2022-12-17        2352
# 2022-12-18        2345
#
# Processing B0CV64188H_raw.pkl
# Found sales rank data for B0CV64188H
# Category: 2619533011
# Data points: 320
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2024-02-23         313
# 2024-02-24         371
# 2024-02-25         372
# 2024-02-26         334
# 2024-02-27         344
#
# Processing B09M7NLLCS_raw.pkl
# Found sales rank data for B09M7NLLCS
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         732
# 2022-12-15         728
# 2022-12-16         722
# 2022-12-17         768
# 2022-12-18         772
#
# Processing B001650NNW_raw.pkl
# Found sales rank data for B001650NNW
# Category: 2619533011
# Data points: 688
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          19
# 2022-12-15          21
# 2022-12-16          25
# 2022-12-17          23
# 2022-12-18          32
#
# Processing B0002DGRSY_raw.pkl
# Found sales rank data for B0002DGRSY
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         137
# 2022-12-15         141
# 2022-12-16         159
# 2022-12-17         160
# 2022-12-18         157
#
# Processing B07NF9VV22_raw.pkl
# Found sales rank data for B07NF9VV22
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        5115
# 2022-12-15        5449
# 2022-12-16        6078
# 2022-12-17        5832
# 2022-12-18        6910
#
# Processing B0CFMYX249_raw.pkl
# Found sales rank data for B0CFMYX249
# Category: 2619533011
# Data points: 494
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-09-06       66089
# 2023-09-07       45510
# 2023-09-08       29509
# 2023-09-09       29388
# 2023-09-10       37648
#
# Processing B07C249HRJ_raw.pkl
# Found sales rank data for B07C249HRJ
# Category: 2619533011
# Data points: 753
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         577
# 2022-12-15         596
# 2022-12-16         718
# 2022-12-17         708
# 2022-12-18         661
#
# Processing B004BFE4EI_raw.pkl
# Found sales rank data for B004BFE4EI
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        2117
# 2022-12-15        1991
# 2022-12-16        2155
# 2022-12-17        2131
# 2022-12-18        2107
#
# Processing B00028ZLHC_raw.pkl
# No valid sales rank reference for /Users/takedownccp/Documents/Cursor/DDU/data/raw_data/B00028ZLHC_raw.pkl
# No valid sales rank data found
#
# Processing B00JN9HCDC_raw.pkl
# Found sales rank data for B00JN9HCDC
# Category: 2619533011
# Data points: 758
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         446
# 2022-12-15         408
# 2022-12-16         499
# 2022-12-17         520
# 2022-12-18         592
#
# Processing B0BW3CVN3V_raw.pkl
# Found sales rank data for B0BW3CVN3V
# Category: 2619533011
# Data points: 672
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-02-22       89008
# 2023-02-23      110262
# 2023-02-24      134599
# 2023-02-25      145501
# 2023-02-26      159848
#
# Processing B013GLAE4Q_raw.pkl
# Found sales rank data for B013GLAE4Q
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1030
# 2022-12-15        1112
# 2022-12-16        1105
# 2022-12-17        1177
# 2022-12-18        1239
#
# Processing B0C618Y9JJ_raw.pkl
# Found sales rank data for B0C618Y9JJ
# Category: 2619533011
# Data points: 585
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-05-30       33729
# 2023-05-31       36946
# 2023-06-01       35039
# 2023-06-02       31364
# 2023-06-03       29761
#
# Processing B00CU2CMOI_raw.pkl
# Found sales rank data for B00CU2CMOI
# Category: 2619533011
# Data points: 754
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          66
# 2022-12-15          87
# 2022-12-16          89
# 2022-12-17          97
# 2022-12-18         105
#
# Processing B0BWBNT8JX_raw.pkl
# Found sales rank data for B0BWBNT8JX
# Category: 2619533011
# Data points: 608
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-05-12       56427
# 2023-05-13       76573
# 2023-05-14       47035
# 2023-05-15       37952
# 2023-05-16       44244
#
# Processing B09G4FD9GP_raw.pkl
# Found sales rank data for B09G4FD9GP
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1028
# 2022-12-15        1150
# 2022-12-16        1206
# 2022-12-17        1162
# 2022-12-18        1105
#
# Processing B08CDHJTCX_raw.pkl
# Found sales rank data for B08CDHJTCX
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         302
# 2022-12-15         340
# 2022-12-16         409
# 2022-12-17         415
# 2022-12-18         386
#
# Processing B00VJLMYA8_raw.pkl
# Found sales rank data for B00VJLMYA8
# Category: 2619533011
# Data points: 758
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         417
# 2022-12-15         386
# 2022-12-16         430
# 2022-12-17         403
# 2022-12-18         426
#
# Processing B00025Z6YI_raw.pkl
# Found sales rank data for B00025Z6YI
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        9495
# 2022-12-15       10662
# 2022-12-16        8585
# 2022-12-17       10189
# 2022-12-18        9406
#
# Processing B0CDYH6TG2_raw.pkl
# No valid sales rank reference for /Users/takedownccp/Documents/Cursor/DDU/data/raw_data/B0CDYH6TG2_raw.pkl
# No valid sales rank data found
#
# Processing B0797HNYKF_raw.pkl
# Found sales rank data for B0797HNYKF
# Category: 2619533011
# Data points: 758
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1693
# 2022-12-15        2884
# 2022-12-16        3533
# 2022-12-17        3425
# 2022-12-18        3564
#
# Processing B07MZN4KXB_raw.pkl
# Found sales rank data for B07MZN4KXB
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         997
# 2022-12-15         918
# 2022-12-16         993
# 2022-12-17         961
# 2022-12-18        1088
#
# Processing B0CTCHN6B2_raw.pkl
# Found sales rank data for B0CTCHN6B2
# Category: 2619533011
# Data points: 345
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2024-02-01       49388
# 2024-02-02       29038
# 2024-02-03       24684
# 2024-02-04       25497
# 2024-02-05       20980
#
# Processing B0081Z77LG_raw.pkl
# Found sales rank data for B0081Z77LG
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        4435
# 2022-12-15        4970
# 2022-12-16        5249
# 2022-12-17        5062
# 2022-12-18        4964
#
# Processing B073WNJFJN_raw.pkl
# Found sales rank data for B073WNJFJN
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14      120027
# 2022-12-15       71064
# 2022-12-16       87240
# 2022-12-17      102832
# 2022-12-18      110729
#
# Processing B00B28RZYI_raw.pkl
# Found sales rank data for B00B28RZYI
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1178
# 2022-12-15        1133
# 2022-12-16        1140
# 2022-12-17        1125
# 2022-12-18        1135
#
# Processing B010IGL3QA_raw.pkl
# Found sales rank data for B010IGL3QA
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        4414
# 2022-12-15        4970
# 2022-12-16        5249
# 2022-12-17        5062
# 2022-12-18        4964
#
# Processing B0872PJTG8_raw.pkl
# Found sales rank data for B0872PJTG8
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         488
# 2022-12-15         437
# 2022-12-16         474
# 2022-12-17         465
# 2022-12-18         463
#
# Processing B0017JANQY_raw.pkl
# Found sales rank data for B0017JANQY
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         272
# 2022-12-15         268
# 2022-12-16         280
# 2022-12-17         294
# 2022-12-18         316
#
# Processing B00YB0D9YE_raw.pkl
# Found sales rank data for B00YB0D9YE
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         129
# 2022-12-15         127
# 2022-12-16         132
# 2022-12-17         133
# 2022-12-18         146
#
# Processing B001FK4BLI_raw.pkl
# Found sales rank data for B001FK4BLI
# Category: 2619533011
# Data points: 561
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-06-30        2406
# 2023-07-01        1689
# 2023-07-02        1294
# 2023-07-03        1146
# 2023-07-04        1186
#
# Processing B07NJ35SWR_raw.pkl
# Found sales rank data for B07NJ35SWR
# Category: 2619533011
# Data points: 755
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         155
# 2022-12-15         154
# 2022-12-16         195
# 2022-12-17         185
# 2022-12-18         171
#
# Processing B074YZKSH4_raw.pkl
# Found sales rank data for B074YZKSH4
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1355
# 2022-12-15        1544
# 2022-12-16        1601
# 2022-12-17        1591
# 2022-12-18        1503
#
# Processing B01A5KLUG2_raw.pkl
# Found sales rank data for B01A5KLUG2
# Category: 2619533011
# Data points: 673
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-03-08         156
# 2023-03-09         162
# 2023-03-10         158
# 2023-03-11         151
# 2023-03-12         148
#
# Processing B0CLLRBHQL_raw.pkl
# Found sales rank data for B0CLLRBHQL
# Category: 2619533011
# Data points: 357
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2024-01-19        3233
# 2024-01-20        3591
# 2024-01-21         670
# 2024-01-22         693
# 2024-01-23         504
#
# Processing B07D5DNXRN_raw.pkl
# Found sales rank data for B07D5DNXRN
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         564
# 2022-12-15         637
# 2022-12-16         683
# 2022-12-17         660
# 2022-12-18         730
#
# Processing B0CTJ63YN8_raw.pkl
# No valid sales rank reference for /Users/takedownccp/Documents/Cursor/DDU/data/raw_data/B0CTJ63YN8_raw.pkl
# No valid sales rank data found
#
# Processing B09VXN6CM3_raw.pkl
# Found sales rank data for B09VXN6CM3
# Category: 2619533011
# Data points: 752
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1787
# 2022-12-15        1825
# 2022-12-16        2119
# 2022-12-17        1902
# 2022-12-18        1733
#
# Processing B00CTJ8E8K_raw.pkl
# Found sales rank data for B00CTJ8E8K
# Category: 2619533011
# Data points: 680
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          13
# 2022-12-16          15
# 2022-12-17          14
# 2022-12-18          17
# 2022-12-19          18
#
# Processing B001650OE0_raw.pkl
# Found sales rank data for B001650OE0
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         434
# 2022-12-15         473
# 2022-12-16         542
# 2022-12-17         607
# 2022-12-18         675
#
# Processing B0B6Q9RGGT_raw.pkl
# Found sales rank data for B0B6Q9RGGT
# Category: 2619533011
# Data points: 718
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        5994
# 2022-12-15        6002
# 2022-12-16        5529
# ...
# Category: 2619533011
# Data points: 754
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         568
# 2022-12-15         572
# 2022-12-16         635
# 2022-12-17         562
# 2022-12-18         560
#
# Processing B00OI20SXA_raw.pkl
# Found sales rank data for B00OI20SXA
# Category: 2619533011
# Data points: 758
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         352
# 2022-12-15         319
# 2022-12-16         362
# 2022-12-17         353
# 2022-12-18         337
#
# Processing B0BMDXN576_raw.pkl
# Found sales rank data for B0BMDXN576
# Category: 2619533011
# Data points: 735
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-01-03       96072
# 2023-01-04      113789
# 2023-01-05      124838
# 2023-01-06      131067
# 2023-01-07      103000
#
# Processing B00M0FHCN6_raw.pkl
# Found sales rank data for B00M0FHCN6
# Category: 2619533011
# Data points: 755
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          73
# 2022-12-15          71
# 2022-12-16          76
# 2022-12-17          81
# 2022-12-18          94
#
# Processing B0C8PNVFWP_raw.pkl
# Found sales rank data for B0C8PNVFWP
# Category: 2619533011
# Data points: 567
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-06-24        1354
# 2023-06-25        1781
# 2023-06-26        2181
# 2023-06-27        2001
# 2023-06-28        2289
#
# Processing B003XKCE1W_raw.pkl
# Found sales rank data for B003XKCE1W
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         685
# 2022-12-15         805
# 2022-12-16         764
# 2022-12-17         821
# 2022-12-18         875
#
# Processing B0CGJG25PV_raw.pkl
# Found sales rank data for B0CGJG25PV
# Category: 2619533011
# Data points: 458
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-10-10       63355
# 2023-10-11      105901
# 2023-10-12      103174
# 2023-10-13      111413
# 2023-10-14       62074
#
# Processing B07584TRYH_raw.pkl
# Found sales rank data for B07584TRYH
# Category: 2619533011
# Data points: 753
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         249
# 2022-12-15         273
# 2022-12-16         259
# 2022-12-17         259
# 2022-12-18         253
#
# Processing B006FSUUSI_raw.pkl
# Found sales rank data for B006FSUUSI
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         788
# 2022-12-15         871
# 2022-12-16         768
# 2022-12-17         814
# 2022-12-18         929
#
# Processing B0002DK4WE_raw.pkl
# No valid sales rank reference for /Users/takedownccp/Documents/Cursor/DDU/data/raw_data/B0002DK4WE_raw.pkl
# No valid sales rank data found
#
# Processing B088BDTMW2_raw.pkl
# Found sales rank data for B088BDTMW2
# Category: 2619533011
# Data points: 755
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          89
# 2022-12-15          94
# 2022-12-16          91
# 2022-12-17          80
# 2022-12-18          81
#
# Processing B002T2BWGI_raw.pkl
# Found sales rank data for B002T2BWGI
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         770
# 2022-12-15         777
# 2022-12-16         813
# 2022-12-17         899
# 2022-12-18         937
#
# Processing B07YNT71MX_raw.pkl
# Found sales rank data for B07YNT71MX
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         853
# 2022-12-15         793
# 2022-12-16         944
# 2022-12-17         924
# 2022-12-18         993
#
# Processing B08WRXCTGW_raw.pkl
# Found sales rank data for B08WRXCTGW
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         540
# 2022-12-15         592
# 2022-12-16         587
# 2022-12-17         535
# 2022-12-18         489
#
# Processing B093TMSTSN_raw.pkl
# Found sales rank data for B093TMSTSN
# Category: 2619533011
# Data points: 746
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         229
# 2022-12-15         226
# 2022-12-16         264
# 2022-12-17         252
# 2022-12-18         218
#
# Processing B0BWBV6158_raw.pkl
# Found sales rank data for B0BWBV6158
# Category: 2619533011
# Data points: 615
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-05-03       61875
# 2023-05-04       49924
# 2023-05-05       36474
# 2023-05-06       69506
# 2023-05-07       82980
#
# Processing B0018CI998_raw.pkl
# Found sales rank data for B0018CI998
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         337
# 2022-12-15         338
# 2022-12-16         348
# 2022-12-17         365
# 2022-12-18         392
#
# Processing B01BMBYKUQ_raw.pkl
# Found sales rank data for B01BMBYKUQ
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         851
# 2022-12-15        1050
# 2022-12-16        1173
# 2022-12-17        1007
# 2022-12-18        1024
#
# Processing B08176S2TX_raw.pkl
# Found sales rank data for B08176S2TX
# Category: 2619533011
# Data points: 746
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         277
# 2022-12-15         288
# 2022-12-16         356
# 2022-12-17         387
# 2022-12-18         329
#
# Processing B001OE5G7I_raw.pkl
# Found sales rank data for B001OE5G7I
# Category: 2619533011
# Data points: 746
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         537
# 2022-12-15         561
# 2022-12-16         522
# 2022-12-17         491
# 2022-12-18         474
#
# Processing B083WM3K3H_raw.pkl
# Found sales rank data for B083WM3K3H
# Category: 2619533011
# Data points: 758
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1074
# 2022-12-15        1252
# 2022-12-16        1292
# 2022-12-17        1259
# 2022-12-18        1291
#
# Processing B07VC5C3C3_raw.pkl
# Found sales rank data for B07VC5C3C3
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         587
# 2022-12-15         550
# 2022-12-16         588
# 2022-12-17         594
# 2022-12-18         584
#
# Processing B07X836SW9_raw.pkl
# Found sales rank data for B07X836SW9
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         992
# 2022-12-15        1001
# 2022-12-16        1068
# 2022-12-17        1029
# 2022-12-18         981
#
# Processing B09V9WC1S1_raw.pkl
# Found sales rank data for B09V9WC1S1
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         240
# 2022-12-15         233
# 2022-12-16         249
# 2022-12-17         268
# 2022-12-18         282
#
# Processing B0C94JBWLN_raw.pkl
# Found sales rank data for B0C94JBWLN
# Category: 2619533011
# Data points: 281
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2024-04-06         531
# 2024-04-07         397
# 2024-04-08         530
# 2024-04-09         513
# 2024-04-10         580
#
# Processing B0002AR0I8_raw.pkl
# Found sales rank data for B0002AR0I8
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14          91
# 2022-12-15          80
# 2022-12-16          73
# 2022-12-17          80
# 2022-12-18          75
#
# Processing B000WT8REK_raw.pkl
# Found sales rank data for B000WT8REK
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         632
# 2022-12-15         622
# 2022-12-16         580
# 2022-12-17         575
# 2022-12-18         543
#
# Processing B09XLGLX5G_raw.pkl
# Found sales rank data for B09XLGLX5G
# Category: 2619533011
# Data points: 753
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1339
# 2022-12-15        1375
# 2022-12-16        1270
# 2022-12-17        1226
# 2022-12-18         995
#
# Processing B0098QN9SC_raw.pkl
# Found sales rank data for B0098QN9SC
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1537
# 2022-12-15        1677
# 2022-12-16        1798
# 2022-12-17        1832
# 2022-12-18        1759
#
# Processing B00063425K_raw.pkl
# Found sales rank data for B00063425K
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         350
# 2022-12-15         367
# 2022-12-16         366
# 2022-12-17         382
# 2022-12-18         391
#
# Processing B09XLGGG3J_raw.pkl
# Found sales rank data for B09XLGGG3J
# Category: 2619533011
# Data points: 753
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1339
# 2022-12-15        1249
# 2022-12-16        1296
# 2022-12-17        1226
# 2022-12-18         995
#
# Processing B001B4TV1I_raw.pkl
# Found sales rank data for B001B4TV1I
# Category: 2619533011
# Data points: 757
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         258
# 2022-12-15         245
# 2022-12-16         246
# 2022-12-17         245
# 2022-12-18         221
#
# Processing B06WLQDW12_raw.pkl
# Found sales rank data for B06WLQDW12
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         482
# 2022-12-15         625
# 2022-12-16         591
# 2022-12-17         567
# 2022-12-18         735
#
# Processing B07SJ914VM_raw.pkl
# Found sales rank data for B07SJ914VM
# Category: 2619533011
# Data points: 756
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         213
# 2022-12-15         221
# 2022-12-16         208
# 2022-12-17         226
# 2022-12-18         244
#
# Processing B08DSS8FHD_raw.pkl
# Found sales rank data for B08DSS8FHD
# Category: 2619533011
# Data points: 758
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         355
# 2022-12-15         347
# 2022-12-16         333
# 2022-12-17         309
# 2022-12-18         278
#
# Processing B0CFLBZS4Y_raw.pkl
# Found sales rank data for B0CFLBZS4Y
# Category: 2619533011
# Data points: 450
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-10-05         375
# 2023-10-06         329
# 2023-10-07         307
# 2023-10-08         280
# 2023-10-09         310
#
# Processing B00QKZAKPY_raw.pkl
# Found sales rank data for B00QKZAKPY
# Category: 2619533011
# Data points: 754
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         219
# 2022-12-15         214
# 2022-12-16         220
# 2022-12-17         227
# 2022-12-18         209
#
# Processing B0CB64XJVN_raw.pkl
# No valid sales rank reference for /Users/takedownccp/Documents/Cursor/DDU/data/raw_data/B0CB64XJVN_raw.pkl
# No valid sales rank data found
#
# Processing B01M6A1ATC_raw.pkl
# Found sales rank data for B01M6A1ATC
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14       37866
# 2022-12-15       40190
# 2022-12-16       43885
# 2022-12-17       33610
# 2022-12-18       40720
#
# Processing B09P3P3L25_raw.pkl
# Found sales rank data for B09P3P3L25
# Category: 2619533011
# Data points: 738
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14        1197
# 2022-12-15        1275
# 2022-12-16        1144
# 2022-12-17        1095
# 2022-12-18        1063
#
# Processing B002S52WX8_raw.pkl
# Found sales rank data for B002S52WX8
# Category: 2619533011
# Data points: 760
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         576
# 2022-12-15         551
# 2022-12-16         610
# 2022-12-17         614
# 2022-12-18         601
#
# Processing B06W5GWSGZ_raw.pkl
# Found sales rank data for B06W5GWSGZ
# Category: 2619533011
# Data points: 755
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         430
# 2022-12-15         493
# 2022-12-16         418
# 2022-12-17         511
# 2022-12-18         464
#
# Processing B0CJLD7YPR_raw.pkl
# Found sales rank data for B0CJLD7YPR
# Category: 2619533011
# Data points: 461
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2023-10-02       68709
# 2023-10-03      111407
# 2023-10-04      125116
# 2023-10-05      133725
# 2023-10-07      102244
#
# Processing B095HZ27WH_raw.pkl
# No valid sales rank reference for /Users/takedownccp/Documents/Cursor/DDU/data/raw_data/B095HZ27WH_raw.pkl
# No valid sales rank data found
#
# Processing B0BZ2VYHNB_raw.pkl
# No valid sales rank reference for /Users/takedownccp/Documents/Cursor/DDU/data/raw_data/B0BZ2VYHNB_raw.pkl
# No valid sales rank data found
#
# Processing B0011XHGR0_raw.pkl
# Found sales rank data for B0011XHGR0
# Category: 3760901
# Data points: 112
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2024-09-24        9720
# 2024-09-25        9377
# 2024-09-26       11504
# 2024-09-27       10113
# 2024-09-28        9595
#
# Processing B01AVI1I06_raw.pkl
# Found sales rank data for B01AVI1I06
# Category: 2619533011
# Data points: 755
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         561
# 2022-12-15         628
# 2022-12-16         717
# 2022-12-17         674
# 2022-12-18         711
#
# Processing B0832578WQ_raw.pkl
# Found sales rank data for B0832578WQ
# Category: 2619533011
# Data points: 759
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         187
# 2022-12-15         155
# 2022-12-16         150
# 2022-12-17         145
# 2022-12-18         141
#
# Processing B07PWB9J43_raw.pkl
# Found sales rank data for B07PWB9J43
# Category: 2619533011
# Data points: 755
# Data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data
#
# First few data points:
#             Sales Rank
# 2022-12-14         389
# 2022-12-15         370
# 2022-12-16         360
# 2022-12-17         354
# 2022-12-18         400
