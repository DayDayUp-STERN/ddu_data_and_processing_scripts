# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from imblearn.over_sampling import SMOTE
import xgboost as xgb
import shap
from scipy import stats
import warnings
from pathlib import Path
import pickle
from datetime import datetime
import pytz
import random
import os
warnings.filterwarnings('ignore')

def keepa_to_est(keepa_time):
    """Convert Keepa time to EST datetime"""
    if isinstance(keepa_time, datetime):
        if keepa_time.tzinfo is None:
            keepa_time = pytz.UTC.localize(keepa_time)
        return keepa_time.astimezone(pytz.timezone('US/Eastern'))
    
    try:
        unix_time = (keepa_time + 21564000) * 60
        utc_time = datetime.fromtimestamp(unix_time, tz=pytz.UTC)
        return utc_time.astimezone(pytz.timezone('US/Eastern'))
    except TypeError as e:
        print(f"Error converting time: {keepa_time}, type: {type(keepa_time)}")
        raise e

def check_data_completeness(df, required_metrics):
    """
    Check if the data contains all required metrics
    Return (is_complete, missing_metrics)
    """
    existing_columns = set(df.columns)
    required_metrics = set(required_metrics)
    missing_metrics = required_metrics - existing_columns
    
    # Check if all required columns exist
    if missing_metrics:
        return False, missing_metrics
    
    # # Check if each column has enough non-null values (e.g., at least 80% of the data)
    # threshold = 0.8
    # for metric in required_metrics:
    #     if df[metric].isna().mean() > (1 - threshold):
    #         missing_metrics.add(f"{metric} (>80% missing)")
    #         return False, missing_metrics
    
    return True, set()

def process_data_to_timeseries(file_path):
    """Convert nested data structure to time series DataFrame"""
    required_metrics = {
        'SALES', 'LISTPRICE', 'BUY_BOX_SHIPPING', 
        'COUNT_REVIEWS', 'RATING'
    }
    
    try:
        with open(file_path, 'rb') as f:
            data = pickle.load(f)
        
        nested_data = data.get('data', {})
        asin = data.get('asin', 'unknown')
        
        metrics = {
            'AMAZON': ['AMAZON_time', 'AMAZON'],
            'NEW': ['NEW_time', 'NEW'],
            'USED': ['USED_time', 'USED'],
            'SALES': ['SALES_time', 'SALES'],
            'LISTPRICE': ['LISTPRICE_time', 'LISTPRICE'],
            'NEW_FBA': ['NEW_FBA_time', 'NEW_FBA'],
            'COUNT_NEW': ['COUNT_NEW_time', 'COUNT_NEW'],
            'RATING': ['RATING_time', 'RATING'],
            'COUNT_REVIEWS': ['COUNT_REVIEWS_time', 'COUNT_REVIEWS'],
            'BUY_BOX_SHIPPING': ['BUY_BOX_SHIPPING_time', 'BUY_BOX_SHIPPING']
        }
        
        time_series_dict = {}
        for metric_name, (time_key, value_key) in metrics.items():
            if time_key in nested_data and value_key in nested_data:
                times = nested_data[time_key]
                values = nested_data[value_key]
                
                if not isinstance(times, (list, np.ndarray)) or not isinstance(values, (list, np.ndarray)):
                    continue
                    
                for t, v in zip(times, values):
                    try:
                        est_time = keepa_to_est(t)
                        if est_time not in time_series_dict:
                            time_series_dict[est_time] = {}
                        time_series_dict[est_time][metric_name] = np.nan if v == -1 else v
                    except Exception as e:
                        print(f"Error processing {metric_name} for {asin}: {str(e)}")
                        continue
        
        if not time_series_dict:
            print(f"No valid data found for {asin}")
            return None, asin
        
        df = pd.DataFrame.from_dict(time_series_dict, orient='index')
        df.sort_index(inplace=True)
        
        # Check data completeness
        is_complete, missing_metrics = check_data_completeness(df, required_metrics)
        if not is_complete:
            print(f"Incomplete data for {asin}. Missing metrics: {missing_metrics}")
            return None, asin
        
        # Basic data check
        if len(df) < 60:  # Ensure at least 60 days of data
            print(f"Insufficient data points for {asin}: {len(df)} < 60 days")
            return None, asin
            
        df = df.ffill().bfill()
        df['ASIN'] = asin
        
        return df, asin
        
    except Exception as e:
        print(f"Error processing file {file_path}: {str(e)}")
        return None, None

def preprocess_data(df):
    """Apply all preprocessing steps"""
    # Replace inf and -inf with 0
    df = df.replace([np.inf, -np.inf], 0)

    # Calculate rolling averages
    df['Sales_rank_rolling_7'] = df['SALES'].rolling(window=7, min_periods=1).mean()
    df['Sales_rank_rolling_30'] = df['SALES'].rolling(window=30, min_periods=1).mean()
    df['Sales_rank_rolling_60'] = df['SALES'].rolling(window=60, min_periods=1).mean()
    df['Sales_rank_rolling_90'] = df['SALES'].rolling(window=90, min_periods=1).mean()
    
    df['List_price_rolling_7'] = df['LISTPRICE'].rolling(window=7, min_periods=1).mean()
    df['List_price_rolling_30'] = df['LISTPRICE'].rolling(window=30, min_periods=1).mean()
    df['Buy_box_price_rolling_7'] = df['BUY_BOX_SHIPPING'].rolling(window=7, min_periods=1).mean()
    df['Buy_box_price_rolling_30'] = df['BUY_BOX_SHIPPING'].rolling(window=30, min_periods=1).mean()
    
    # Calculate price changes (use clip to avoid -inf)
    df['List_price_change_7'] = df['LISTPRICE'].pct_change(periods=7).clip(-1, 1) * 100
    df['Buy_box_price_change_7'] = df['BUY_BOX_SHIPPING'].pct_change(periods=7).clip(-1, 1) * 100
    
    # Calculate review metrics
    df['New_reviews'] = df['COUNT_REVIEWS'].diff(periods=7).fillna(0)
    df['Review_growth_rate'] = df['COUNT_REVIEWS'].pct_change().clip(-1, 1) * 100
    
    # Calculate future metrics
    future_sales_rank = df['SALES'].shift(-30)
    current_sales_rank = df['SALES']
    df['Sales_rank_change_30d'] = ((future_sales_rank - current_sales_rank) / current_sales_rank).clip(-1, 1) * 100
    df['Sales_rank_change_30d'] = df['Sales_rank_change_30d'].fillna(0) # Ensure no NaN values
    
    # Calculate Go_viral - if the sales rank change is less than -30% (which means the sales rank is increased by more than 30%), then it is viral
    df['Go_viral'] = (df['Sales_rank_change_30d'] < -30).astype(int)

    # Check the ratio of Go_viral
    viral_ratio = df['Go_viral'].mean()
    print(f"\nViral ratio for ASIN {df['ASIN'].iloc[0]}: {viral_ratio:.2%}")

    #   Save the value of Go_viral, ensuring that subsequent processing will not change it
    go_viral_values = df['Go_viral'].copy()
    
    # If the viral ratio is less than 5%, return None, discard this ASIN
    # Because the data is not enough to train a good model
    if viral_ratio < 0.05:
        print(f"Insufficient viral ratio ({viral_ratio:.2%} < 5%) for ASIN {df['ASIN'].iloc[0]}")
        return None
    

    #  处理缺失值和异常值（除了Go_viral和ASIN）
    for col in df.columns:
        if col in ['Go_viral', 'ASIN']:  #   Skip these columns
            continue
            
        if df[col].dtype in ['float64', 'int64']:
            # For rolling and change features, use forward and backward filling
            if col.endswith(('_7', '_30', '_60', '_90', '_change_7', '_change_30d')):
                df[col] = df[col].ffill().bfill()
            else:
                # For other numeric columns, handle outliers and fill with median
                q1 = df[col].quantile(0.25)
                q3 = df[col].quantile(0.75)
                iqr = q3 - q1
                lower_bound = q1 - 1.5 * iqr
                upper_bound = q3 + 1.5 * iqr
                df[col] = df[col].clip(lower_bound, upper_bound)
                df[col] = df[col].fillna(df[col].median())

    # Rename columns for consistency
    df = df.rename(columns={
        'SALES': 'Sales_rank',
        'LISTPRICE': 'List_price',
        'BUY_BOX_SHIPPING': 'Buy_box_price',
        'COUNT_REVIEWS': 'Review_count',
        'RATING': 'Rating'
    })

    #   Restore the original value of Go_viral
    df['Go_viral'] = go_viral_values
    
    
    return df



def perform_time_series_analysis(X, y, features, max_train_ratio=0.8, random_state=42):
    """
    Use simplified time series analysis
    
    Parameters:
    -----------
    X : DataFrame
        Feature data, arranged in chronological order
    y : Series
        Target variable (Go_viral)
    features : list
        Feature name list
    max_train_ratio : float
        Training set ratio
    random_state : int
        Random seed
    """
    total_samples = len(X)
    print(f"\nTotal samples: {total_samples}")

    #### 1. Pearson Correlation Analysis ####
    # Calculate the feature correlation
    print("\nCalculating feature correlations...")
    data_for_corr = X.copy()
    data_for_corr['Go_viral'] = y
    correlation_matrix = data_for_corr.corr(method='pearson')
    
    # Create the correlation heatmap
    plt.figure(figsize=(12, 10))
    sns.heatmap(correlation_matrix, 
                annot=True,
                cmap='coolwarm',
                center=0,
                fmt='.2f',
                square=True)
    plt.title('Feature Correlation Heatmap')
    plt.tight_layout()
    
    # Save the heatmap
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    heatmap_path = f'/Users/takedownccp/Documents/Cursor/DDU/data/results/correlation_heatmap_{timestamp}.png'
    plt.savefig(heatmap_path)
    plt.close()
    print(f"Correlation heatmap saved to {heatmap_path}")
    
    # Print the correlation with Go_viral
    viral_correlations = correlation_matrix['Go_viral'].sort_values(ascending=False)
    print("\nCorrelations with Go_viral:")
    print(viral_correlations)


    
    # Simple time series split
    train_size = int(total_samples * max_train_ratio)
    X_train, X_test = X.iloc[:train_size], X.iloc[train_size:]
    y_train, y_test = y.iloc[:train_size], y.iloc[train_size:]
    
    print("\nDataset split:")
    print(f"Training set size: {len(X_train)}")
    print(f"Test set size: {len(X_test)}")
    print(f"Training set viral ratio: {y_train.mean():.2%}")
    print(f"Test set viral ratio: {y_test.mean():.2%}")
    
    #   Standardize features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    

    #### 2. Logistic Regression ####
    # Logistic Regression
    lr_model = LogisticRegression(
        random_state=random_state,
        class_weight='balanced',
        max_iter=1000
    )
    lr_model.fit(X_train_scaled, y_train)
    lr_pred = lr_model.predict(X_test_scaled)
    
    # Calculate LR performance metrics
    lr_metrics = {
        'accuracy': accuracy_score(y_test, lr_pred),
        'precision': precision_score(y_test, lr_pred),
        'recall': recall_score(y_test, lr_pred),
        'f1': f1_score(y_test, lr_pred)
    }
    

    #### 3. XGBoost ####
    # XGBoost
    xgb_model = xgb.XGBClassifier(
        random_state=random_state,
        scale_pos_weight=len(y_train[y_train==0])/max(1, len(y_train[y_train==1])),
        eval_metric='logloss'
    )
    
    xgb_model.fit(
        X_train, y_train,
        eval_set=[(X_test, y_test)],
        verbose=False
    )
    xgb_pred = xgb_model.predict(X_test)
    
    # Calculate XGB performance metrics
    xgb_metrics = {
        'accuracy': accuracy_score(y_test, xgb_pred),
        'precision': precision_score(y_test, xgb_pred),
        'recall': recall_score(y_test, xgb_pred),
        'f1': f1_score(y_test, xgb_pred)
    }
    
    # Feature Importance 
    lr_importance = pd.DataFrame({
        'Feature': features,
        'Coefficient': lr_model.coef_[0],
        'Abs_Coefficient': abs(lr_model.coef_[0])
    }).sort_values('Abs_Coefficient', ascending=False)
    
    xgb_importance = pd.DataFrame({
        'Feature': features,
        'Importance': xgb_model.feature_importances_
    }).sort_values('Importance', ascending=False)
    
    # SHAP Analysis
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_test)
    
    # SHAP Analysis and Visualization
    print("\nGenerating SHAP analysis...")
    explainer = shap.TreeExplainer(xgb_model)
    shap_values = explainer.shap_values(X_test)
    
    # SHAP Summary Plot
    plt.figure(figsize=(10, 8))
    shap.summary_plot(shap_values, X_test, feature_names=features, show=False)
    plt.title('SHAP Summary Plot')
    shap_path = f'/Users/takedownccp/Documents/Cursor/DDU/data/results/shap_summary_{timestamp}.png'
    plt.savefig(shap_path, bbox_inches='tight')
    plt.close()
    print(f"SHAP summary plot saved to {shap_path}")
    
    # SHAP Bar Plot
    plt.figure(figsize=(10, 8))
    shap.summary_plot(shap_values, X_test, feature_names=features, plot_type='bar', show=False)
    shap_bar_path = f'/Users/takedownccp/Documents/Cursor/DDU/data/results/shap_importance_{timestamp}.png'
    plt.savefig(shap_bar_path, bbox_inches='tight')
    plt.close()
    print(f"SHAP importance plot saved to {shap_bar_path}")
    
    #  Print SHAP value statistics
    print("\nSHAP Value Statistics:")
    shap_df = pd.DataFrame(shap_values, columns=features)
    shap_importance = pd.DataFrame({
        'Feature': features,
        'Mean_SHAP': np.abs(shap_df).mean()
    }).sort_values('Mean_SHAP', ascending=False)
    print(shap_importance)
    
    # Save results
    results = {
        'correlations': viral_correlations,
        'lr_importance': lr_importance,
        'xgb_importance': xgb_importance,
        'shap_importance': shap_importance,
        'metrics': pd.DataFrame({
            'model': ['Logistic Regression', 'XGBoost'],
            'accuracy': [lr_metrics['accuracy'], xgb_metrics['accuracy']],
            'precision': [lr_metrics['precision'], xgb_metrics['precision']],
            'recall': [lr_metrics['recall'], xgb_metrics['recall']],
            'f1': [lr_metrics['f1'], xgb_metrics['f1']]
        })
    }
    
    #  Save results to CSV
    # results_path = f'/Users/takedownccp/Documents/Cursor/DDU/data/results/analysis_results_{timestamp}.csv'
    # with pd.ExcelWriter(results_path) as writer:
    #     results['correlations'].to_excel(writer, sheet_name='Correlations')
    #     results['lr_importance'].to_excel(writer, sheet_name='LR_Importance')
    #     results['xgb_importance'].to_excel(writer, sheet_name='XGB_Importance')
    #     results['shap_importance'].to_excel(writer, sheet_name='SHAP_Importance')
    #     results['metrics'].to_excel(writer, sheet_name='Model_Metrics')
    # print(f"\nAnalysis results saved to {results_path}")
    
    return (lr_importance, xgb_importance, results['metrics'], 
            xgb_model, shap_values, X_test)


def analyze_data(df, results_dir, max_attempts=10):
    """Perform all analyses with retry mechanism"""
    for attempt in range(max_attempts):
        try:
            print(f"\nAnalysis attempt {attempt + 1}/{max_attempts}")
            
            # 1. Correlation Analysis
            numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns
            correlations = df[numerical_cols].corr()['Go_viral'].sort_values(ascending=False)
            
            # 2. Prepare features
            features = ['Sales_rank', 'List_price', 'Buy_box_price', 'Review_count', 'Rating',
                       'Sales_rank_rolling_7', 'Sales_rank_rolling_30', 'Sales_rank_rolling_60', 
                       'Sales_rank_rolling_90','List_price_rolling_7', 'List_price_rolling_30',
                       'Buy_box_price_rolling_7','Buy_box_price_rolling_30', 'List_price_change_7',
                       'Buy_box_price_change_7', 'New_reviews', 'Review_growth_rate']
            
            X = df[features]
            y = df['Go_viral']
            
            #  3. Execute time series analysis - use the correct parameters
            lr_importance, xgb_importance, metrics_df, final_model, shap_values, final_test_data = perform_time_series_analysis(
                X=X,
                y=y,
                features=features,
                # min_positive_samples=10,  # Ensure at least 10 positive samples
                max_train_ratio=0.8,      # Maximum training set ratio
                random_state=42+attempt   # Use different random seeds for each attempt
            )
            
            #  Save model metrics
            metrics_path = Path(results_dir) / f'model_metrics_{datetime.now().strftime("%Y%m%d_%H%M%S")}.csv'
            metrics_df.to_csv(metrics_path, index=False)
            print(f"\nModel metrics saved to {metrics_path}")
            
            print("\nAnalysis completed successfully!")
            return correlations, lr_importance, xgb_importance, final_model
            
        except Exception as e:
            print(f"Attempt {attempt + 1} failed with error: {str(e)}")
            if attempt == max_attempts - 1:
                raise Exception(f"Analysis failed after {max_attempts} attempts")
            continue


def get_project_paths():
    """Get all project-related paths"""
    # Use the current working directory in Jupyter Notebook
    current_dir = Path.cwd()
    
    # If the current directory is 'src', then the parent directory is the project root
    if current_dir.name == 'src':
        project_root = current_dir.parent
    else:
        # Otherwise, assume the current directory is the project root
        project_root = current_dir
    
     # Construct all necessary paths
    paths = {
        'root': project_root,
        'raw_data': project_root / 'data' / 'raw_data',
        'processed_data': project_root / 'data' / 'processed_data',
        'results': project_root / 'results'
    }
    
    # Ensure that the required directories exist
    paths['processed_data'].mkdir(parents=True, exist_ok=True)
    paths['results'].mkdir(parents=True, exist_ok=True)
    
    # Verify that the raw_data directory exists
    if not paths['raw_data'].exists():
        raise FileNotFoundError(f"Raw data directory not found at {paths['raw_data']}")
        
    # Print the current path information (for debugging)
    print(f"Current directory: {current_dir}")
    print(f"Project root: {project_root}")
    print(f"Raw data path: {paths['raw_data']}")
    
    return paths




def main():
    """Main execution function"""
    # Get project paths
    try:
        paths = get_project_paths()
    except FileNotFoundError as e:
        print(f"Error: {e}")
        return
    
    # Get timestamp (all files share the same timestamp)
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    
    # Get pkl file list
    pkl_files = list(paths['raw_data'].glob('*_raw.pkl'))
    if not pkl_files:
        print(f"No pkl files found in {paths['raw_data']}")
        return
        
    print(f"Found {len(pkl_files)} pkl files in {paths['raw_data']}")
    
    successful_files = []
    valid_dfs = []
    processed_asins = set()
    max_attempts = len(pkl_files)
    attempts = 0
    
    while len(valid_dfs) <= 100 and attempts < max_attempts:
        remaining_files = [f for f in pkl_files if f.stem.split('_')[0] not in processed_asins]
        if not remaining_files:
            break
            
        file_path = random.choice(remaining_files)
        asin = file_path.stem.split('_')[0]
        processed_asins.add(asin)
        
        print(f"\nProcessing {file_path.name}...")
        try:
            df, current_asin = process_data_to_timeseries(file_path)
            if df is not None:
                df = preprocess_data(df)
                if df is not None:  # viral比例足够
                    valid_dfs.append(df)
                    successful_files.append(file_path)  # 保存成功的文件路径
                    print(f"Successfully processed {current_asin}, viral ratio: {df['Go_viral'].mean():.2%}")
                else:
                    print(f"Skipped {asin} due to insufficient viral ratio")
            else:
                print(f"Skipped {asin} due to invalid or incomplete data")
        except Exception as e:
            print(f"Error processing {asin}: {str(e)}")
        
        attempts += 1
        print(f"Progress: {len(valid_dfs)}/100 valid files found ({attempts}/{max_attempts} attempts)")
    
    if not valid_dfs:
        print("No valid data files found after processing")
        return
    
    
    # Merge all dataframes
    final_df = pd.concat(valid_dfs, ignore_index=True)

    viral_ratio = final_df['Go_viral'].mean()
    print(f"\nViral ratio for final_df: {viral_ratio:.2%}")

    
    # Save processed data
    output_path = paths['processed_data'] / f'processed_timeseries_{timestamp}.csv'
    final_df.to_csv(output_path, index=False)
    print(f"\nProcessed data saved to {output_path}")
    
    # Analyze data
    try:
        print("\nStarting data analysis...")
        correlations, lr_importance, xgb_importance, xgb_model = analyze_data(final_df, paths['results'])
        
        # Print results
        print("\n=== Analysis Results ===")
        print("\nTop 10 Correlations with Go_viral:")
        print(correlations.head(10))
        
        print("\nTop 10 Important Features (Logistic Regression):")
        print(lr_importance.head(10))
        
        print("\nTop 10 Important Features (XGBoost):")
        print(xgb_importance.head(10))
        
        # Save analysis results
        results_path = paths['results'] / f'analysis_results_{timestamp}.csv'
        results_df = pd.DataFrame({
            'Feature': lr_importance['Feature'],
            'LR_Coefficient': lr_importance['Coefficient'],
            'XGB_Importance': xgb_importance['Importance']
        })
        results_df.to_csv(results_path, index=False)
        print(f"\nAnalysis results saved to {results_path}")
        
    except Exception as e:
        print(f"\nError during analysis: {str(e)}")
        print("Analysis results not saved due to error")
    
    # Print summary
    print("\n=== Processing Summary ===")
    print(f"Total files attempted: {attempts}")
    print(f"Successfully processed files: {len(valid_dfs)}")
    print(f"Files with sufficient viral ratio: {len(valid_dfs)}")
    print(f"Timestamp: {timestamp}")
    print("\nOutput files:")
    print(f"- Processed data: processed_timeseries_{timestamp}.csv")
    print(f"- Meta information: selected_asins_meta_{timestamp}.csv")
    print(f"- Analysis results: analysis_results_{timestamp}.csv")
    print(f"- Correlation heatmap: correlation_heatmap_{timestamp}.png")
    print(f"- SHAP importance plot: shap_importance_{timestamp}.png")


if __name__ == "__main__":
    main()
# Out:
# Current directory: /Users/takedownccp/Documents/Cursor/DDU/src
# Project root: /Users/takedownccp/Documents/Cursor/DDU
# Raw data path: /Users/takedownccp/Documents/Cursor/DDU/data/raw_data
# Found 909 pkl files in /Users/takedownccp/Documents/Cursor/DDU/data/raw_data
#
# Processing B08L7LD72W_raw.pkl...
#
# Viral ratio for ASIN B08L7LD72W: 8.03%
# Successfully processed B08L7LD72W, viral ratio: 8.03%
# Progress: 1/100 valid files found (1/909 attempts)
#
# Processing B07D562VQ6_raw.pkl...
#
# Viral ratio for ASIN B07D562VQ6: 8.73%
# Successfully processed B07D562VQ6, viral ratio: 8.73%
# Progress: 2/100 valid files found (2/909 attempts)
#
# Processing B000PKWKMQ_raw.pkl...
#
# Viral ratio for ASIN B000PKWKMQ: 7.91%
# Successfully processed B000PKWKMQ, viral ratio: 7.91%
# Progress: 3/100 valid files found (3/909 attempts)
#
# Processing B01MRLPOK6_raw.pkl...
#
# Viral ratio for ASIN B01MRLPOK6: 8.53%
# Successfully processed B01MRLPOK6, viral ratio: 8.53%
# Progress: 4/100 valid files found (4/909 attempts)
#
# Processing B08HPHF91C_raw.pkl...
#
# Viral ratio for ASIN B08HPHF91C: 8.35%
# Successfully processed B08HPHF91C, viral ratio: 8.35%
# Progress: 5/100 valid files found (5/909 attempts)
#
# Processing B08MKP1TMD_raw.pkl...
#
# Viral ratio for ASIN B08MKP1TMD: 6.82%
# Successfully processed B08MKP1TMD, viral ratio: 6.82%
# Progress: 6/100 valid files found (6/909 attempts)
#
# Processing B00VC8GSZ0_raw.pkl...
#
# Viral ratio for ASIN B00VC8GSZ0: 7.77%
# Successfully processed B00VC8GSZ0, viral ratio: 7.77%
# Progress: 7/100 valid files found (7/909 attempts)
#
# Processing B00R03WJ1I_raw.pkl...
#
# Viral ratio for ASIN B00R03WJ1I: 4.21%
# Insufficient viral ratio (4.21% < 5%) for ASIN B00R03WJ1I
# Skipped B00R03WJ1I due to insufficient viral ratio
# Progress: 7/100 valid files found (8/909 attempts)
#
# Processing B0056EAKUA_raw.pkl...
#
# Viral ratio for ASIN B0056EAKUA: 8.05%
# Successfully processed B0056EAKUA, viral ratio: 8.05%
# Progress: 8/100 valid files found (9/909 attempts)
#
# Processing B08ZKVWS6N_raw.pkl...
#
# Viral ratio for ASIN B08ZKVWS6N: 5.12%
# Successfully processed B08ZKVWS6N, viral ratio: 5.12%
# Progress: 9/100 valid files found (10/909 attempts)
#
# Processing B079X44DB8_raw.pkl...
#
# Viral ratio for ASIN B079X44DB8: 7.43%
# Successfully processed B079X44DB8, viral ratio: 7.43%
# Progress: 10/100 valid files found (11/909 attempts)
#
# Processing B078H2YFD4_raw.pkl...
#
# Viral ratio for ASIN B078H2YFD4: 12.24%
# Successfully processed B078H2YFD4, viral ratio: 12.24%
# Progress: 11/100 valid files found (12/909 attempts)
#
# Processing B01AMTU1ZM_raw.pkl...
#
# Viral ratio for ASIN B01AMTU1ZM: 4.47%
# Insufficient viral ratio (4.47% < 5%) for ASIN B01AMTU1ZM
# Skipped B01AMTU1ZM due to insufficient viral ratio
# Progress: 11/100 valid files found (13/909 attempts)
#
# Processing B073SZ6NT8_raw.pkl...
#
# Viral ratio for ASIN B073SZ6NT8: 7.30%
# Successfully processed B073SZ6NT8, viral ratio: 7.30%
# Progress: 12/100 valid files found (14/909 attempts)
#
# Processing B07M9S9V3T_raw.pkl...
#
# Viral ratio for ASIN B07M9S9V3T: 7.68%
# Successfully processed B07M9S9V3T, viral ratio: 7.68%
# Progress: 13/100 valid files found (15/909 attempts)
#
# Processing B07L717Z9H_raw.pkl...
#
# Viral ratio for ASIN B07L717Z9H: 3.89%
# Insufficient viral ratio (3.89% < 5%) for ASIN B07L717Z9H
# Skipped B07L717Z9H due to insufficient viral ratio
# Progress: 13/100 valid files found (16/909 attempts)
#
# Processing B0797HNYKF_raw.pkl...
#
# Viral ratio for ASIN B0797HNYKF: 9.47%
# Successfully processed B0797HNYKF, viral ratio: 9.47%
# Progress: 14/100 valid files found (17/909 attempts)
#
# Processing B07BCSJ1XJ_raw.pkl...
#
# Viral ratio for ASIN B07BCSJ1XJ: 5.63%
# Successfully processed B07BCSJ1XJ, viral ratio: 5.63%
# Progress: 15/100 valid files found (18/909 attempts)
#
# Processing B01FZ6N0MI_raw.pkl...
#
# Viral ratio for ASIN B01FZ6N0MI: 15.12%
# Successfully processed B01FZ6N0MI, viral ratio: 15.12%
# Progress: 16/100 valid files found (19/909 attempts)
#
# Processing B006AYMMRY_raw.pkl...
#
# Viral ratio for ASIN B006AYMMRY: 7.97%
# Successfully processed B006AYMMRY, viral ratio: 7.97%
# Progress: 17/100 valid files found (20/909 attempts)
#
# Processing B07J393YLG_raw.pkl...
#
# Viral ratio for ASIN B07J393YLG: 9.12%
# Successfully processed B07J393YLG, viral ratio: 9.12%
# Progress: 18/100 valid files found (21/909 attempts)
#
# Processing B00WZZQ46C_raw.pkl...
#
# Viral ratio for ASIN B00WZZQ46C: 5.43%
# Successfully processed B00WZZQ46C, viral ratio: 5.43%
# Progress: 19/100 valid files found (22/909 attempts)
#
# Processing B01GBSSKVU_raw.pkl...
#
# Viral ratio for ASIN B01GBSSKVU: 5.72%
# Successfully processed B01GBSSKVU, viral ratio: 5.72%
# Progress: 20/100 valid files found (23/909 attempts)
#
# Processing B0002DK8N4_raw.pkl...
#
# Viral ratio for ASIN B0002DK8N4: 10.37%
# Successfully processed B0002DK8N4, viral ratio: 10.37%
# Progress: 21/100 valid files found (24/909 attempts)
#
# Processing B08FL57QSJ_raw.pkl...
#
# Viral ratio for ASIN B08FL57QSJ: 13.75%
# Successfully processed B08FL57QSJ, viral ratio: 13.75%
# Progress: 22/100 valid files found (25/909 attempts)
#
# Processing B00ZDJ787Q_raw.pkl...
#
# Viral ratio for ASIN B00ZDJ787Q: 6.38%
# Successfully processed B00ZDJ787Q, viral ratio: 6.38%
# Progress: 23/100 valid files found (26/909 attempts)
#
# Processing B01BMBPOJ2_raw.pkl...
#
# Viral ratio for ASIN B01BMBPOJ2: 8.60%
# Successfully processed B01BMBPOJ2, viral ratio: 8.60%
# Progress: 24/100 valid files found (27/909 attempts)
#
# Processing B0C6Q1C7LV_raw.pkl...
#
# Viral ratio for ASIN B0C6Q1C7LV: 26.09%
# Successfully processed B0C6Q1C7LV, viral ratio: 26.09%
# Progress: 25/100 valid files found (28/909 attempts)
#
# Processing B0CC8PKQ2T_raw.pkl...
#
# Viral ratio for ASIN B0CC8PKQ2T: 24.68%
# Successfully processed B0CC8PKQ2T, viral ratio: 24.68%
# Progress: 26/100 valid files found (29/909 attempts)
#
# Processing B09621WZXM_raw.pkl...
#
# Viral ratio for ASIN B09621WZXM: 13.40%
# Successfully processed B09621WZXM, viral ratio: 13.40%
# Progress: 27/100 valid files found (30/909 attempts)
#
# Processing B0CVVDHZWN_raw.pkl...
#
# Viral ratio for ASIN B0CVVDHZWN: 21.09%
# Successfully processed B0CVVDHZWN, viral ratio: 21.09%
# Progress: 28/100 valid files found (31/909 attempts)
#
# Processing B0BZ2VYHNB_raw.pkl...
#
# Viral ratio for ASIN B0BZ2VYHNB: 3.08%
# Insufficient viral ratio (3.08% < 5%) for ASIN B0BZ2VYHNB
# Skipped B0BZ2VYHNB due to insufficient viral ratio
# Progress: 28/100 valid files found (32/909 attempts)
#
# Processing B00OP6SVJW_raw.pkl...
#
# Viral ratio for ASIN B00OP6SVJW: 5.41%
# Successfully processed B00OP6SVJW, viral ratio: 5.41%
# Progress: 29/100 valid files found (33/909 attempts)
#
# Processing B07ZPMYYZF_raw.pkl...
#
# Viral ratio for ASIN B07ZPMYYZF: 2.76%
# Insufficient viral ratio (2.76% < 5%) for ASIN B07ZPMYYZF
# Skipped B07ZPMYYZF due to insufficient viral ratio
# Progress: 29/100 valid files found (34/909 attempts)
#
# Processing B006FTJ0NI_raw.pkl...
#
# Viral ratio for ASIN B006FTJ0NI: 10.29%
# Successfully processed B006FTJ0NI, viral ratio: 10.29%
# Progress: 30/100 valid files found (35/909 attempts)
#
# Processing B000V5NVQ4_raw.pkl...
#
# Viral ratio for ASIN B000V5NVQ4: 13.11%
# Successfully processed B000V5NVQ4, viral ratio: 13.11%
# Progress: 31/100 valid files found (36/909 attempts)
#
# Processing B07MZN4KXB_raw.pkl...
#
# Viral ratio for ASIN B07MZN4KXB: 8.70%
# Successfully processed B07MZN4KXB, viral ratio: 8.70%
# Progress: 32/100 valid files found (37/909 attempts)
#
# Processing B07SJ914VM_raw.pkl...
#
# Viral ratio for ASIN B07SJ914VM: 12.76%
# Successfully processed B07SJ914VM, viral ratio: 12.76%
# Progress: 33/100 valid files found (38/909 attempts)
#
# Processing B0CV64188H_raw.pkl...
#
# Viral ratio for ASIN B0CV64188H: 1.48%
# Insufficient viral ratio (1.48% < 5%) for ASIN B0CV64188H
# Skipped B0CV64188H due to insufficient viral ratio
# Progress: 33/100 valid files found (39/909 attempts)
#
# Processing B09K8MHNQ9_raw.pkl...
#
# Viral ratio for ASIN B09K8MHNQ9: 13.85%
# Successfully processed B09K8MHNQ9, viral ratio: 13.85%
# Progress: 34/100 valid files found (40/909 attempts)
#
# Processing B09R2BFL61_raw.pkl...
#
# Viral ratio for ASIN B09R2BFL61: 5.45%
# Successfully processed B09R2BFL61, viral ratio: 5.45%
# Progress: 35/100 valid files found (41/909 attempts)
#
# Processing B000EBIP6G_raw.pkl...
#
# Viral ratio for ASIN B000EBIP6G: 11.92%
# Successfully processed B000EBIP6G, viral ratio: 11.92%
# Progress: 36/100 valid files found (42/909 attempts)
#
# Processing B003O7ZON4_raw.pkl...
#
# Viral ratio for ASIN B003O7ZON4: 4.54%
# Insufficient viral ratio (4.54% < 5%) for ASIN B003O7ZON4
# Skipped B003O7ZON4 due to insufficient viral ratio
# Progress: 36/100 valid files found (43/909 attempts)
#
# Processing B06XJY5H5S_raw.pkl...
#
# Viral ratio for ASIN B06XJY5H5S: 6.71%
# Successfully processed B06XJY5H5S, viral ratio: 6.71%
# Progress: 37/100 valid files found (44/909 attempts)
#
# Processing B0CB9185QG_raw.pkl...
#
# Viral ratio for ASIN B0CB9185QG: 13.33%
# Successfully processed B0CB9185QG, viral ratio: 13.33%
# Progress: 38/100 valid files found (45/909 attempts)
#
# Processing B0192NCAB2_raw.pkl...
#
# Viral ratio for ASIN B0192NCAB2: 8.20%
# Successfully processed B0192NCAB2, viral ratio: 8.20%
# Progress: 39/100 valid files found (46/909 attempts)
#
# Processing B0B3NFQDTD_raw.pkl...
#
# Viral ratio for ASIN B0B3NFQDTD: 12.15%
# Successfully processed B0B3NFQDTD, viral ratio: 12.15%
# Progress: 40/100 valid files found (47/909 attempts)
#
# Processing B0CLD3GTHV_raw.pkl...
#
# Viral ratio for ASIN B0CLD3GTHV: 12.83%
# Successfully processed B0CLD3GTHV, viral ratio: 12.83%
# Progress: 41/100 valid files found (48/909 attempts)
#
# Processing B001HX427G_raw.pkl...
#
# Viral ratio for ASIN B001HX427G: 8.86%
# Successfully processed B001HX427G, viral ratio: 8.86%
# Progress: 42/100 valid files found (49/909 attempts)
#
# Processing B000MD2H3S_raw.pkl...
#
# Viral ratio for ASIN B000MD2H3S: 4.57%
# Insufficient viral ratio (4.57% < 5%) for ASIN B000MD2H3S
# Skipped B000MD2H3S due to insufficient viral ratio
# Progress: 42/100 valid files found (50/909 attempts)
#
# Processing B07P488YBD_raw.pkl...
#
# Viral ratio for ASIN B07P488YBD: 6.81%
# Successfully processed B07P488YBD, viral ratio: 6.81%
# Progress: 43/100 valid files found (51/909 attempts)
#
# Processing B0BNNXWTK7_raw.pkl...
#
# Viral ratio for ASIN B0BNNXWTK7: 9.92%
# Successfully processed B0BNNXWTK7, viral ratio: 9.92%
# Progress: 44/100 valid files found (52/909 attempts)
#
# Processing B003YM2QJY_raw.pkl...
#
# Viral ratio for ASIN B003YM2QJY: 8.43%
# Successfully processed B003YM2QJY, viral ratio: 8.43%
# Progress: 45/100 valid files found (53/909 attempts)
#
# Processing B09NF8QLSY_raw.pkl...
#
# Viral ratio for ASIN B09NF8QLSY: 7.83%
# Successfully processed B09NF8QLSY, viral ratio: 7.83%
# Progress: 46/100 valid files found (54/909 attempts)
#
# Processing B0131GM34U_raw.pkl...
#
# Viral ratio for ASIN B0131GM34U: 7.62%
# Successfully processed B0131GM34U, viral ratio: 7.62%
# Progress: 47/100 valid files found (55/909 attempts)
#
# Processing B008BE7Z6O_raw.pkl...
#
# Viral ratio for ASIN B008BE7Z6O: 8.20%
# Successfully processed B008BE7Z6O, viral ratio: 8.20%
# Progress: 48/100 valid files found (56/909 attempts)
#
# Processing B095C81X3M_raw.pkl...
#
# Viral ratio for ASIN B095C81X3M: 12.32%
# Successfully processed B095C81X3M, viral ratio: 12.32%
# Progress: 49/100 valid files found (57/909 attempts)
#
# Processing B0088BE38S_raw.pkl...
#
# Viral ratio for ASIN B0088BE38S: 16.43%
# Successfully processed B0088BE38S, viral ratio: 16.43%
# Progress: 50/100 valid files found (58/909 attempts)
#
# Processing B01AVI1I06_raw.pkl...
#
# Viral ratio for ASIN B01AVI1I06: 4.28%
# Insufficient viral ratio (4.28% < 5%) for ASIN B01AVI1I06
# Skipped B01AVI1I06 due to insufficient viral ratio
# Progress: 50/100 valid files found (59/909 attempts)
#
# Processing B07FK2M4XG_raw.pkl...
#
# Viral ratio for ASIN B07FK2M4XG: 5.65%
# Successfully processed B07FK2M4XG, viral ratio: 5.65%
# Progress: 51/100 valid files found (60/909 attempts)
#
# Processing B0002DGRSY_raw.pkl...
#
# Viral ratio for ASIN B0002DGRSY: 2.78%
# Insufficient viral ratio (2.78% < 5%) for ASIN B0002DGRSY
# Skipped B0002DGRSY due to insufficient viral ratio
# Progress: 51/100 valid files found (61/909 attempts)
#
# Processing B008ESYADS_raw.pkl...
#
# Viral ratio for ASIN B008ESYADS: 6.70%
# Successfully processed B008ESYADS, viral ratio: 6.70%
# Progress: 52/100 valid files found (62/909 attempts)
#
# Processing B01H3OA816_raw.pkl...
#
# Viral ratio for ASIN B01H3OA816: 14.67%
# Successfully processed B01H3OA816, viral ratio: 14.67%
# Progress: 53/100 valid files found (63/909 attempts)
#
# Processing B093K7D53V_raw.pkl...
#
# Viral ratio for ASIN B093K7D53V: 11.07%
# Successfully processed B093K7D53V, viral ratio: 11.07%
# Progress: 54/100 valid files found (64/909 attempts)
#
# Processing B07GL8SLKY_raw.pkl...
#
# Viral ratio for ASIN B07GL8SLKY: 11.58%
# Successfully processed B07GL8SLKY, viral ratio: 11.58%
# Progress: 55/100 valid files found (65/909 attempts)
#
# Processing B09D7DF4DB_raw.pkl...
#
# Viral ratio for ASIN B09D7DF4DB: 15.36%
# Successfully processed B09D7DF4DB, viral ratio: 15.36%
# Progress: 56/100 valid files found (66/909 attempts)
#
# Processing B08THGBXZP_raw.pkl...
#
# Viral ratio for ASIN B08THGBXZP: 11.89%
# Successfully processed B08THGBXZP, viral ratio: 11.89%
# Progress: 57/100 valid files found (67/909 attempts)
#
# Processing B008EHLZP0_raw.pkl...
#
# Viral ratio for ASIN B008EHLZP0: 15.82%
# Successfully processed B008EHLZP0, viral ratio: 15.82%
# Progress: 58/100 valid files found (68/909 attempts)
#
# Processing B001VIY9F2_raw.pkl...
#
# Viral ratio for ASIN B001VIY9F2: 11.40%
# Successfully processed B001VIY9F2, viral ratio: 11.40%
# Progress: 59/100 valid files found (69/909 attempts)
#
# Processing B09DJGXWKW_raw.pkl...
#
# Viral ratio for ASIN B09DJGXWKW: 7.75%
# Successfully processed B09DJGXWKW, viral ratio: 7.75%
# Progress: 60/100 valid files found (70/909 attempts)
#
# Processing B08QJMZPNH_raw.pkl...
#
# Viral ratio for ASIN B08QJMZPNH: 6.96%
# Successfully processed B08QJMZPNH, viral ratio: 6.96%
# Progress: 61/100 valid files found (71/909 attempts)
#
# Processing B0C33KN3FX_raw.pkl...
#
# Viral ratio for ASIN B0C33KN3FX: 13.08%
# Successfully processed B0C33KN3FX, viral ratio: 13.08%
# Progress: 62/100 valid files found (72/909 attempts)
#
# Processing B0CFMYX249_raw.pkl...
#
# Viral ratio for ASIN B0CFMYX249: 9.00%
# Successfully processed B0CFMYX249, viral ratio: 9.00%
# Progress: 63/100 valid files found (73/909 attempts)
#
# Processing B0748H3GKN_raw.pkl...
#
# Viral ratio for ASIN B0748H3GKN: 3.66%
# Insufficient viral ratio (3.66% < 5%) for ASIN B0748H3GKN
# Skipped B0748H3GKN due to insufficient viral ratio
# Progress: 63/100 valid files found (74/909 attempts)
#
# Processing B0BHKW54MR_raw.pkl...
#
# Viral ratio for ASIN B0BHKW54MR: 4.74%
# Insufficient viral ratio (4.74% < 5%) for ASIN B0BHKW54MR
# Skipped B0BHKW54MR due to insufficient viral ratio
# Progress: 63/100 valid files found (75/909 attempts)
#
# Processing B00DR940MA_raw.pkl...
#
# Viral ratio for ASIN B00DR940MA: 8.66%
# Successfully processed B00DR940MA, viral ratio: 8.66%
# Progress: 64/100 valid files found (76/909 attempts)
#
# Processing B07CX9STN3_raw.pkl...
#
# Viral ratio for ASIN B07CX9STN3: 15.13%
# Successfully processed B07CX9STN3, viral ratio: 15.13%
# Progress: 65/100 valid files found (77/909 attempts)
#
# Processing B0C2VJB8PR_raw.pkl...
# Incomplete data for B0C2VJB8PR. Missing metrics: {'LISTPRICE'}
# Skipped B0C2VJB8PR due to invalid or incomplete data
# Progress: 65/100 valid files found (78/909 attempts)
#
# Processing B0BZZC5PMF_raw.pkl...
#
# Viral ratio for ASIN B0BZZC5PMF: 5.47%
# Successfully processed B0BZZC5PMF, viral ratio: 5.47%
# Progress: 66/100 valid files found (79/909 attempts)
#
# Processing B08FBGRKYT_raw.pkl...
#
# Viral ratio for ASIN B08FBGRKYT: 12.93%
# Successfully processed B08FBGRKYT, viral ratio: 12.93%
# Progress: 67/100 valid files found (80/909 attempts)
#
# Processing B00YB0D9YE_raw.pkl...
#
# Viral ratio for ASIN B00YB0D9YE: 11.00%
# Successfully processed B00YB0D9YE, viral ratio: 11.00%
# Progress: 68/100 valid files found (81/909 attempts)
#
# Processing B087QTCXPS_raw.pkl...
#
# Viral ratio for ASIN B087QTCXPS: 5.56%
# Successfully processed B087QTCXPS, viral ratio: 5.56%
# Progress: 69/100 valid files found (82/909 attempts)
#
# Processing B0BCX4939V_raw.pkl...
#
# Viral ratio for ASIN B0BCX4939V: 6.10%
# Successfully processed B0BCX4939V, viral ratio: 6.10%
# Progress: 70/100 valid files found (83/909 attempts)
#
# Processing B0CQ9J8JFZ_raw.pkl...
#
# Viral ratio for ASIN B0CQ9J8JFZ: 4.81%
# Insufficient viral ratio (4.81% < 5%) for ASIN B0CQ9J8JFZ
# Skipped B0CQ9J8JFZ due to insufficient viral ratio
# Progress: 70/100 valid files found (84/909 attempts)
#
# Processing B07QB8LPCD_raw.pkl...
#
# Viral ratio for ASIN B07QB8LPCD: 9.89%
# Successfully processed B07QB8LPCD, viral ratio: 9.89%
# Progress: 71/100 valid files found (85/909 attempts)
#
# Processing B009IOCCD2_raw.pkl...
#
# Viral ratio for ASIN B009IOCCD2: 10.37%
# Successfully processed B009IOCCD2, viral ratio: 10.37%
# Progress: 72/100 valid files found (86/909 attempts)
#
# Processing B001QCSHLK_raw.pkl...
#
# Viral ratio for ASIN B001QCSHLK: 7.97%
# Successfully processed B001QCSHLK, viral ratio: 7.97%
# Progress: 73/100 valid files found (87/909 attempts)
#
# Processing B00CTJ8E8K_raw.pkl...
#
# Viral ratio for ASIN B00CTJ8E8K: 11.38%
# Successfully processed B00CTJ8E8K, viral ratio: 11.38%
# Progress: 74/100 valid files found (88/909 attempts)
#
# Processing B0CFLBZS4Y_raw.pkl...
#
# Viral ratio for ASIN B0CFLBZS4Y: 21.69%
# Successfully processed B0CFLBZS4Y, viral ratio: 21.69%
# Progress: 75/100 valid files found (89/909 attempts)
#
# Processing B08C9PHWFC_raw.pkl...
#
# Viral ratio for ASIN B08C9PHWFC: 10.12%
# Successfully processed B08C9PHWFC, viral ratio: 10.12%
# Progress: 76/100 valid files found (90/909 attempts)
#
# Processing B00JN9JEJC_raw.pkl...
#
# Viral ratio for ASIN B00JN9JEJC: 19.39%
# Successfully processed B00JN9JEJC, viral ratio: 19.39%
# Progress: 77/100 valid files found (91/909 attempts)
#
# Processing B08HP69PT8_raw.pkl...
#
# Viral ratio for ASIN B08HP69PT8: 9.12%
# Successfully processed B08HP69PT8, viral ratio: 9.12%
# Progress: 78/100 valid files found (92/909 attempts)
#
# Processing B0017JFIDC_raw.pkl...
#
# Viral ratio for ASIN B0017JFIDC: 5.77%
# Successfully processed B0017JFIDC, viral ratio: 5.77%
# Progress: 79/100 valid files found (93/909 attempts)
#
# Processing B0CW4WKQVJ_raw.pkl...
#
# Viral ratio for ASIN B0CW4WKQVJ: 3.75%
# Insufficient viral ratio (3.75% < 5%) for ASIN B0CW4WKQVJ
# Skipped B0CW4WKQVJ due to insufficient viral ratio
# Progress: 79/100 valid files found (94/909 attempts)
#
# Processing B0CRDZ7KLK_raw.pkl...
#
# Viral ratio for ASIN B0CRDZ7KLK: 14.23%
# Successfully processed B0CRDZ7KLK, viral ratio: 14.23%
# Progress: 80/100 valid files found (95/909 attempts)
#
# Processing B07NF9VV22_raw.pkl...
#
# Viral ratio for ASIN B07NF9VV22: 11.25%
# Successfully processed B07NF9VV22, viral ratio: 11.25%
# Progress: 81/100 valid files found (96/909 attempts)
#
# Processing B01BMG7WME_raw.pkl...
#
# Viral ratio for ASIN B01BMG7WME: 8.53%
# Successfully processed B01BMG7WME, viral ratio: 8.53%
# Progress: 82/100 valid files found (97/909 attempts)
#
# Processing B000MCVGEA_raw.pkl...
#
# Viral ratio for ASIN B000MCVGEA: 3.49%
# Insufficient viral ratio (3.49% < 5%) for ASIN B000MCVGEA
# Skipped B000MCVGEA due to insufficient viral ratio
# Progress: 82/100 valid files found (98/909 attempts)
#
# Processing B008BDV86S_raw.pkl...
#
# Viral ratio for ASIN B008BDV86S: 12.68%
# Successfully processed B008BDV86S, viral ratio: 12.68%
# Progress: 83/100 valid files found (99/909 attempts)
#
# Processing B00RVMMHWO_raw.pkl...
#
# Viral ratio for ASIN B00RVMMHWO: 11.08%
# Successfully processed B00RVMMHWO, viral ratio: 11.08%
# Progress: 84/100 valid files found (100/909 attempts)
#
# Processing B00P0H6836_raw.pkl...
#
# Viral ratio for ASIN B00P0H6836: 3.85%
# Insufficient viral ratio (3.85% < 5%) for ASIN B00P0H6836
# Skipped B00P0H6836 due to insufficient viral ratio
# Progress: 84/100 valid files found (101/909 attempts)
#
# Processing B07KYLBRT4_raw.pkl...
#
# Viral ratio for ASIN B07KYLBRT4: 8.67%
# Successfully processed B07KYLBRT4, viral ratio: 8.67%
# Progress: 85/100 valid files found (102/909 attempts)
#
# Processing B0BCX754DW_raw.pkl...
#
# Viral ratio for ASIN B0BCX754DW: 6.67%
# Successfully processed B0BCX754DW, viral ratio: 6.67%
# Progress: 86/100 valid files found (103/909 attempts)
#
# Processing B001QCKS4O_raw.pkl...
#
# Viral ratio for ASIN B001QCKS4O: 9.95%
# Successfully processed B001QCKS4O, viral ratio: 9.95%
# Progress: 87/100 valid files found (104/909 attempts)
#
# Processing B076YHCXPR_raw.pkl...
#
# Viral ratio for ASIN B076YHCXPR: 7.40%
# Successfully processed B076YHCXPR, viral ratio: 7.40%
# Progress: 88/100 valid files found (105/909 attempts)
#
# Processing B0CPHNSV71_raw.pkl...
#
# Viral ratio for ASIN B0CPHNSV71: 5.32%
# Successfully processed B0CPHNSV71, viral ratio: 5.32%
# Progress: 89/100 valid files found (106/909 attempts)
#
# Processing B0BYNF9GZS_raw.pkl...
#
# Viral ratio for ASIN B0BYNF9GZS: 18.72%
# Successfully processed B0BYNF9GZS, viral ratio: 18.72%
# Progress: 90/100 valid files found (107/909 attempts)
#
# Processing B0BWB7K5GN_raw.pkl...
#
# Viral ratio for ASIN B0BWB7K5GN: 6.14%
# Successfully processed B0BWB7K5GN, viral ratio: 6.14%
# Progress: 91/100 valid files found (108/909 attempts)
#
# Processing B01H3OA7KI_raw.pkl...
#
# Viral ratio for ASIN B01H3OA7KI: 9.89%
# Successfully processed B01H3OA7KI, viral ratio: 9.89%
# Progress: 92/100 valid files found (109/909 attempts)
#
# Processing B095HZ27WH_raw.pkl...
#
# Viral ratio for ASIN B095HZ27WH: 5.74%
# Successfully processed B095HZ27WH, viral ratio: 5.74%
# Progress: 93/100 valid files found (110/909 attempts)
#
# Processing B06WLQDW12_raw.pkl...
#
# Viral ratio for ASIN B06WLQDW12: 9.48%
# Successfully processed B06WLQDW12, viral ratio: 9.48%
# Progress: 94/100 valid files found (111/909 attempts)
#
# Processing B00VTQASK6_raw.pkl...
#
# Viral ratio for ASIN B00VTQASK6: 8.62%
# Successfully processed B00VTQASK6, viral ratio: 8.62%
# Progress: 95/100 valid files found (112/909 attempts)
#
# Processing B00MUS5D0M_raw.pkl...
#
# Viral ratio for ASIN B00MUS5D0M: 11.55%
# Successfully processed B00MUS5D0M, viral ratio: 11.55%
# Progress: 96/100 valid files found (113/909 attempts)
#
# Processing B083FHNR68_raw.pkl...
#
# Viral ratio for ASIN B083FHNR68: 3.78%
# Insufficient viral ratio (3.78% < 5%) for ASIN B083FHNR68
# Skipped B083FHNR68 due to insufficient viral ratio
# Progress: 96/100 valid files found (114/909 attempts)
#
# Processing B0BHL4C4MW_raw.pkl...
#
# Viral ratio for ASIN B0BHL4C4MW: 4.41%
# Insufficient viral ratio (4.41% < 5%) for ASIN B0BHL4C4MW
# Skipped B0BHL4C4MW due to insufficient viral ratio
# Progress: 96/100 valid files found (115/909 attempts)
#
# Processing B01BVRL4UA_raw.pkl...
#
# Viral ratio for ASIN B01BVRL4UA: 8.29%
# Successfully processed B01BVRL4UA, viral ratio: 8.29%
# Progress: 97/100 valid files found (116/909 attempts)
#
# Processing B01H0PQSLC_raw.pkl...
#
# Viral ratio for ASIN B01H0PQSLC: 4.83%
# Insufficient viral ratio (4.83% < 5%) for ASIN B01H0PQSLC
# Skipped B01H0PQSLC due to insufficient viral ratio
# Progress: 97/100 valid files found (117/909 attempts)
#
# Processing B010IGL3QA_raw.pkl...
#
# Viral ratio for ASIN B010IGL3QA: 12.15%
# Successfully processed B010IGL3QA, viral ratio: 12.15%
# Progress: 98/100 valid files found (118/909 attempts)
#
# Processing B082L3QQCB_raw.pkl...
#
# Viral ratio for ASIN B082L3QQCB: 12.70%
# Successfully processed B082L3QQCB, viral ratio: 12.70%
# Progress: 99/100 valid files found (119/909 attempts)
#
# Processing B01KZECQQ6_raw.pkl...
#
# Viral ratio for ASIN B01KZECQQ6: 5.13%
# Successfully processed B01KZECQQ6, viral ratio: 5.13%
# Progress: 100/100 valid files found (120/909 attempts)
#
# Processing B001FK4BLI_raw.pkl...
#
# Viral ratio for ASIN B001FK4BLI: 2.33%
# Insufficient viral ratio (2.33% < 5%) for ASIN B001FK4BLI
# Skipped B001FK4BLI due to insufficient viral ratio
# Progress: 100/100 valid files found (121/909 attempts)
#
# Processing B00PB35ZYM_raw.pkl...
#
# Viral ratio for ASIN B00PB35ZYM: 12.47%
# Successfully processed B00PB35ZYM, viral ratio: 12.47%
# Progress: 101/100 valid files found (122/909 attempts)
#
# Viral ratio for final_df: 9.48%
#
# Processed data saved to /Users/takedownccp/Documents/Cursor/DDU/data/processed_data/processed_timeseries_20250210_225023.csv
#
# Starting data analysis...
#
# Analysis attempt 1/10
#
# Total samples: 1670795
#
# Calculating feature correlations...
# Correlation heatmap saved to /Users/takedownccp/Documents/Cursor/DDU/data/results/correlation_heatmap_20250210_225110.png
#
# Correlations with Go_viral:
# Go_viral                    1.000000
# Sales_rank                  0.098867
# Sales_rank_rolling_7        0.090022
# Sales_rank_rolling_30       0.083269
# Sales_rank_rolling_60       0.080401
# Sales_rank_rolling_90       0.079605
# List_price_rolling_30       0.014763
# Buy_box_price_rolling_30    0.014740
# List_price_rolling_7        0.014676
# List_price                  0.014430
# Buy_box_price_rolling_7     0.013953
# Buy_box_price               0.013549
# Review_growth_rate          0.001916
# List_price_change_7         0.000299
# New_reviews                -0.004632
# Buy_box_price_change_7     -0.011394
# Rating                     -0.016011
# Review_count               -0.025731
# Name: Go_viral, dtype: float64
#
# Dataset split:
# Training set size: 1336636
# Test set size: 334159
# Training set viral ratio: 9.42%
# Test set viral ratio: 9.72%
#
# Generating SHAP analysis...
# SHAP summary plot saved to /Users/takedownccp/Documents/Cursor/DDU/data/results/shap_summary_20250210_225110.png
# SHAP importance plot saved to /Users/takedownccp/Documents/Cursor/DDU/data/results/shap_importance_20250210_225110.png
#
# SHAP Value Statistics:
#                                            Feature  Mean_SHAP
# Sales_rank_rolling_7          Sales_rank_rolling_7   0.787049
# Sales_rank                              Sales_rank   0.585188
# Sales_rank_rolling_90        Sales_rank_rolling_90   0.272953
# Review_count                          Review_count   0.220959
# Sales_rank_rolling_60        Sales_rank_rolling_60   0.177773
# List_price                              List_price   0.169264
# Buy_box_price_rolling_30  Buy_box_price_rolling_30   0.158993
# Rating                                      Rating   0.154217
# List_price_rolling_30        List_price_rolling_30   0.147661
# List_price_rolling_7          List_price_rolling_7   0.141436
# Sales_rank_rolling_30        Sales_rank_rolling_30   0.140742
# Buy_box_price                        Buy_box_price   0.139219
# Buy_box_price_rolling_7    Buy_box_price_rolling_7   0.096941
# New_reviews                            New_reviews   0.039794
# Buy_box_price_change_7      Buy_box_price_change_7   0.020763
# Review_growth_rate              Review_growth_rate   0.005955
# List_price_change_7            List_price_change_7   0.002301
#
# Model metrics saved to /Users/takedownccp/Documents/Cursor/DDU/results/model_metrics_20250210_225259.csv
#
# Analysis completed successfully!
#
# === Analysis Results ===
#
# Top 10 Correlations with Go_viral:
# Go_viral                    1.000000
# Sales_rank                  0.098867
# Sales_rank_rolling_7        0.090022
# Sales_rank_rolling_30       0.083269
# Sales_rank_rolling_60       0.080401
# Sales_rank_rolling_90       0.079605
# NEW_FBA                     0.026367
# NEW                         0.019331
# List_price_rolling_30       0.014763
# Buy_box_price_rolling_30    0.014740
# Name: Go_viral, dtype: float64
#
# Top 10 Important Features (Logistic Regression):
#                      Feature  Coefficient  Abs_Coefficient
# 5       Sales_rank_rolling_7     0.535473         0.535473
# 12  Buy_box_price_rolling_30     0.466829         0.466829
# 2              Buy_box_price    -0.443088         0.443088
# 10     List_price_rolling_30     0.300813         0.300813
# 11   Buy_box_price_rolling_7    -0.281796         0.281796
# 1                 List_price     0.245349         0.245349
# 9       List_price_rolling_7    -0.216313         0.216313
# 6      Sales_rank_rolling_30    -0.205014         0.205014
# 0                 Sales_rank     0.124888         0.124888
# 3               Review_count    -0.107291         0.107291
#
# Top 10 Important Features (XGBoost):
#                      Feature  Importance
# 5       Sales_rank_rolling_7    0.178155
# 8      Sales_rank_rolling_90    0.081974
# 4                     Rating    0.075650
# 1                 List_price    0.072943
# 0                 Sales_rank    0.066365
# 10     List_price_rolling_30    0.063850
# 14    Buy_box_price_change_7    0.056230
# 12  Buy_box_price_rolling_30    0.053942
# 2              Buy_box_price    0.052010
# 3               Review_count    0.050063
#
# Analysis results saved to /Users/takedownccp/Documents/Cursor/DDU/results/analysis_results_20250210_225023.csv
#
# === Processing Summary ===
# Total files attempted: 122
# Successfully processed files: 101
# Files with sufficient viral ratio: 101
# Timestamp: 20250210_225023
#
# Output files:
# - Processed data: processed_timeseries_20250210_225023.csv
# - Meta information: selected_asins_meta_20250210_225023.csv
# - Analysis results: analysis_results_20250210_225023.csv
# - Correlation heatmap: correlation_heatmap_20250210_225023.png
# - SHAP importance plot: shap_importance_20250210_225023.png
